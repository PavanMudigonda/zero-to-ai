# %% [markdown]
# # Chapter 10: Higher Order Derivatives## Derivatives of Derivativesf'(x) = first derivative (velocity)  f''(x) = second derivative (acceleration)  f'''(x) = third derivative (jerk)

# %%
import numpy as npimport matplotlib.pyplot as pltimport seaborn as snssns.set_style('whitegrid')plt.rcParams['figure.figsize'] = (14, 10)

# %% [markdown]
# Second derivative measures curvature!
