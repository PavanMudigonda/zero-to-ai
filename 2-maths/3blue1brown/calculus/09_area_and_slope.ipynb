# %% [markdown]
# # Chapter 9: What Does Area Have to Do with Slope?## The Fundamental Theorem ExplainedWhy are derivatives and integrals inverses?This is the deepest insight in calculus!

# %%
import numpy as npimport matplotlib.pyplot as pltimport seaborn as snssns.set_style('whitegrid')plt.rcParams['figure.figsize'] = (14, 10)

# %% [markdown]
# The area function A(x) = ∫₀ˣ f(t)dt has derivative A'(x) = f(x)!
