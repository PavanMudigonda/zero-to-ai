# %% [markdown]
# # Chapter 2: Gradient Descent## How Neural Networks Learn### Cost FunctionMeasures how bad the network performs:C(w,b) = average of (desired - actual)²

# %%
import numpy as npimport matplotlib.pyplot as pltimport seaborn as snsfrom matplotlib.patches import Circlesns.set_style('whitegrid')plt.rcParams['figure.figsize'] = (16, 10)np.random.seed(42)

# %% [markdown]
# ## Gradient DescentImagine finding the lowest point in a foggy valley:1. Check which direction is steepest downhill2. Take a small step3. Repeat!Update rule: w_new = w_old - η∇C

# %%
# Simple gradient descent demoimport numpy as npw = 4.0for i in range(10):    grad = 2*(w-2)  # derivative    w = w - 0.3*grad    print(f"Step {i}: w={w:.4f}")print(f"Final: {w:.4f}")

# %% [markdown]
# ## Stochastic Gradient DescentUse mini-batches instead of all data!Much faster and works well.

# %% [markdown]
# **Next**: Backpropagation - computing gradients efficiently!
