# %% [markdown]
# # Chapter 9: Diffusion Models## A Different ApproachInstead of next-word prediction:1. Start with noise2. Gradually denoise3. Create image!Like running randomness backwards.

# %%
import numpy as npimport matplotlib.pyplot as pltimport seaborn as snsfrom matplotlib.patches import Circlesns.set_style('whitegrid')plt.rcParams['figure.figsize'] = (16, 10)np.random.seed(42)

# %% [markdown]
# ## How Diffusion Works### Training1. Take real image2. Add noise gradually  3. Train network to predict noise### Generation1. Start with pure noise2. Denoise step by step3. Get realistic image!**Applications**: DALL-E, Stable Diffusion, Midjourney

# %%
# Diffusion conceptimport numpy as npprint("Forward: Image → Noise")print("Reverse: Noise → Image")print("\nTrained on millions of images!")
