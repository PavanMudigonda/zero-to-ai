# %% [markdown]
# # Chapter 8: How GPT Stores Facts## Factual KnowledgeGPT knows: 'Paris is the capital of France'**Where is this stored?**Distributed across many weights!

# %%
import numpy as npimport matplotlib.pyplot as pltimport seaborn as snsfrom matplotlib.patches import Circlesns.set_style('whitegrid')plt.rcParams['figure.figsize'] = (16, 10)np.random.seed(42)

# %% [markdown]
# ## Mechanistic InterpretabilityFacts stored in:- **Early layers**: Basic patterns- **Middle layers**: Factual associations  - **Late layers**: Task-specificExample: 'Michael Jordan plays' → 'basketball'Lives in specific attention heads!
