# %% [markdown]
# # Chapter 4: Fourier Series and Complex Exponentials## Decomposing FunctionsAny periodic function can be written as a sum of sines and cosines!$$f(x) = \sum_{n=0}^{\infty} [a_n \cos(nx) + b_n \sin(nx)]$$This is a **Fourier series**.

# %%
import numpy as npimport matplotlib.pyplot as pltimport seaborn as snsfrom matplotlib.animation import FuncAnimationfrom IPython.display import HTMLsns.set_style('whitegrid')plt.rcParams['figure.figsize'] = (14, 10)np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# ## Complex ExponentialsEuler's formula: e^(iθ) = cos(θ) + i·sin(θ)This unifies sines and cosines into elegant exponentials!
