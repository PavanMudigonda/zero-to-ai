# %% [markdown]
# <div className="mx-auto max-w-5xl px-4 py-12 text-center">
#   <h1 className="text-5xl font-extrabold tracking-tight text-slate-900 dark:text-white sm:text-7xl">
#     🚀 Zero to AI
#   </h1>
#   <p className="mx-auto mt-6 max-w-2xl text-xl text-slate-600 dark:text-slate-400">
#     Your Open Source Journey to Master Artificial Intelligence, Machine Learning, Data Science, and Large Language Models.
#   </p>
#   <div className="mt-10 flex justify-center gap-4">
#     <a href="/00-course-setup" className="inline-flex items-center justify-center rounded-lg bg-blue-600 px-6 py-3 text-base font-medium text-white transition-colors hover:bg-blue-700">
#       start learning →
#     </a>
#     <a href="https://github.com/PavanMudigonda/zero-to-ai" target="_blank" rel="noreferrer" className="inline-flex items-center justify-center rounded-lg bg-slate-100 px-6 py-3 text-base font-medium text-slate-700 transition-colors hover:bg-slate-200 dark:bg-slate-800 dark:text-slate-200 dark:hover:bg-slate-700">
#       ★ star on github
#     </a>
#   </div>
# </div>
#
# ---
#
# ### 📚 Course Modules
#
# Explore our complete curriculum going from foundational programming to advanced AI engineering.
#
# import { Cards } from 'nextra/components'
#
# <Cards num={3}>
#   <Cards.Card title="1. Course Setup" href="/00-course-setup" arrow />
#   <Cards.Card title="2. Python" href="/01-python" arrow />
#   <Cards.Card title="3. Data Science" href="/02-data-science" arrow />
#   <Cards.Card title="4. Maths" href="/03-maths" arrow />
#   <Cards.Card title="5. Token" href="/04-token" arrow />
#   <Cards.Card title="6. Embeddings" href="/05-embeddings" arrow />
#   <Cards.Card title="7. Neural Networks" href="/06-neural-networks" arrow />
#   <Cards.Card title="8. Vector Databases" href="/07-vector-databases" arrow />
#   <Cards.Card title="9. Rag" href="/08-rag" arrow />
#   <Cards.Card title="10. Mlops" href="/09-mlops" arrow />
#   <Cards.Card title="11. Specializations" href="/10-specializations" arrow />
#   <Cards.Card title="12. Prompt Engineering" href="/11-prompt-engineering" arrow />
#   <Cards.Card title="13. Llm Finetuning" href="/12-llm-finetuning" arrow />
#   <Cards.Card title="14. Multimodal" href="/13-multimodal" arrow />
#   <Cards.Card title="15. Local Llms" href="/14-local-llms" arrow />
#   <Cards.Card title="16. Ai Agents" href="/15-ai-agents" arrow />
#   <Cards.Card title="17. Model Evaluation" href="/16-model-evaluation" arrow />
#   <Cards.Card title="18. Debugging Troubleshooting" href="/17-debugging-troubleshooting" arrow />
#   <Cards.Card title="19. Low Code Ai Tools" href="/18-low-code-ai-tools" arrow />
#   <Cards.Card title="20. Ai Safety Redteaming" href="/19-ai-safety-redteaming" arrow />
#   <Cards.Card title="21. Real Time Streaming" href="/20-real-time-streaming" arrow />
#   <Cards.Card title="22. Quizzes" href="/21-quizzes" arrow />
#   <Cards.Card title="23. References" href="/22-references" arrow />
#   <Cards.Card title="24. Glossary" href="/23-glossary" arrow />
#   <Cards.Card title="25. Advanced Deep Learning" href="/24-advanced-deep-learning" arrow />
#   <Cards.Card title="26. Reinforcement Learning" href="/25-reinforcement-learning" arrow />
#   <Cards.Card title="27. Time Series Analysis" href="/26-time-series-analysis" arrow />
#   <Cards.Card title="28. Causal Inference" href="/27-causal-inference" arrow />
#   <Cards.Card title="29. Practical Data Science" href="/28-practical-data-science" arrow />
#   <Cards.Card title="30. Ai Hardware Llm Validation" href="/29-ai-hardware-llm-validation" arrow />
#   <Cards.Card title="31. Inference Optimization" href="/30-inference-optimization" arrow />
#   <Cards.Card title="32. Ai Powered Dev Tools" href="/31-ai-powered-dev-tools" arrow />
#   <Cards.Card title="33. Cheatsheets" href="/32-cheatsheets" arrow />
#   <Cards.Card title="34. Roadmaps" href="/33-roadmaps" arrow />
# </Cards>
