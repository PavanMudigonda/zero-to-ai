# %% [markdown]
# https://dev.to/aws-builders/system-design-for-devops-engineers-45lh
#
# https://kodekloud.com/blog/exploring-system-architecture-for-devops-engineers/
#
# https://niqdev.github.io/devops/system-design/
#
#
# https://github.com/donnemartin/system-design-primer
#
#
# https://www.gologic.ca/en/choosing-the-right-devops-training/
#
#
# https://jg.gg/2016/07/31/architecture-and-systems-design-interview/
#
#
# https://martinfowler.com/books/continuousDelivery.html
#
# https://blog.pragmaticengineer.com/preparing-for-the-systems-design-and-coding-interviews/
