# %% [markdown]
# ## Core IdeaSoft-margin SVMs balance margin width and violations through $C$. Kernels replace inner products to create nonlinear boundaries without explicitly constructing all transformed features.

# %%
import numpy as np
from sklearn.datasets import make_moons
from sklearn.svm import SVC

X, y = make_moons(n_samples=200, noise=0.15, random_state=42)
linear = SVC(kernel='linear').fit(X, y)
rbf = SVC(kernel='rbf', gamma='scale').fit(X, y)

print('linear accuracy:', linear.score(X, y))
print('RBF accuracy:', rbf.score(X, y))
print('RBF support vectors:', len(rbf.support_))

# %% [markdown]
# ## Key TakeawaysOnly support vectors determine the fitted boundary. Kernel and regularization choices control flexibility.

# %% [markdown]
# ---
#
# ## License and attribution
#
# This notebook was adapted and generalized from educational material by Chris van de Weth. Text and figures are licensed under [CC BY 4.0](https://creativecommons.org/licenses/by/4.0/); code is copyright (c) 2025 Chris van de Weth and licensed under the [MIT License](https://opensource.org/license/mit). Changes include removing project branding, generalizing educational class names, and normalizing notebook metadata. [Original source](https://github.com/chrisvdweth/selene).
