# %% [markdown]
# # Video Courses & YouTube Channels
#
# > **Status:** Complete — curated guide to the best free and paid video resources for AI/ML learning.
#
# This notebook catalogs the highest-quality video content for each phase of the Zero-to-AI curriculum.
# Use it to supplement any phase where a different teaching style or visual explanation helps.
#
# ---
#
# ## Free YouTube Channels
#
# ### Foundational AI/ML
#
# | Channel | Focus | Subscriber Scale | Best For |
# |---------|-------|-----------------|----------|
# | [3Blue1Brown](https://www.youtube.com/@3blue1brown) | Visual math: linear algebra, calculus, neural networks | 6M+ | Phases 3, 6 |
# | [Andrej Karpathy](https://www.youtube.com/@AndrejKarpathy) | Deep dives: GPT from scratch, tokenization | 1M+ | Phases 4, 6, 12 |
# | [StatQuest with Josh Starmer](https://www.youtube.com/@statquest) | Statistics, ML algorithms (animated) | 1M+ | Phases 2, 3, 5 |
# | [Sentdex](https://www.youtube.com/@sentdex) | Python, ML, NLP tutorials | 1M+ | Phases 1, 2, 6 |
# | [DeepLearning.AI](https://www.youtube.com/@Deeplearningai) | Short explainers + full course replays | 500K+ | All phases |
#
# ### LLMs & Transformers
#
# | Channel | Focus | Best For |
# |---------|-------|----------|
# | [Umar Jamil](https://www.youtube.com/@umarjamilai) | Transformer/diffusion model implementations from scratch | Phases 6, 12 |
# | [Sebastian Raschka](https://www.youtube.com/@SebastianRaschka) | LLM internals, fine-tuning | Phases 6, 12 |
# | [Yannic Kilcher](https://www.youtube.com/@YannicKilcher) | Paper walkthroughs (BERT, GPT, LoRA, etc.) | Phases 6, 12 |
# | [AI Explained](https://www.youtube.com/@aiexplained-official) | Current AI research, GPT-4 analysis | Phases 6, 10 |
#
# ### Agents & Applied AI
#
# | Channel | Focus | Best For |
# |---------|-------|----------|
# | [Matthew Berman](https://www.youtube.com/@matthew_berman) | Local LLMs, agents, workflows | Phases 14, 15 |
# | [Sam Witteveen](https://www.youtube.com/@samwitteveenai) | LangChain, LlamaIndex, Agents | Phases 8, 15 |
# | [Dave Ebbelaar](https://www.youtube.com/@daveebbelaar) | LangGraph, production AI systems | Phase 15 |
# | [AI Jason](https://www.youtube.com/@AIJasonZ) | No-code + code AI tools | Phases 18, 15 |
#
# ---
#
# ## Free Structured Video Courses
#
# ### Machine Learning Foundations
#
# | Course | Platform | Duration | Best For |
# |--------|----------|----------|----------|
# | [CS229: Machine Learning](https://www.youtube.com/playlist?list=PLoROMvodv4rMiGQp3WXShtMGgzqpfVfbU) (Andrew Ng, Stanford) | YouTube | 20h | Phase 2–3 |
# | [Neural Networks: Zero to Hero](https://www.youtube.com/playlist?list=PLAqhIrjkxbuWI23v9cThsA9GvCAUhRvKZ) (Karpathy) | YouTube | 12h | Phases 4, 6 |
# | [fast.ai Practical Deep Learning](https://course.fast.ai/) | fast.ai | 20h | Phases 6, 12 |
# | [MIT 6.S191: Intro to Deep Learning](http://introtodeeplearning.com/) | MIT/YouTube | 10h | Phase 6 |
#
# ### NLP & LLMs
#
# | Course | Platform | Duration | Best For |
# |--------|----------|----------|----------|
# | [Stanford CS224N: NLP with Deep Learning](https://web.stanford.edu/class/cs224n/) | YouTube | 25h | Phases 5, 6, 12 |
# | [Hugging Face NLP Course](https://huggingface.co/learn/nlp-course) | huggingface.co | 15h | Phases 4, 5, 12 |
# | [LLM Course (Maxime Labonne)](https://github.com/mlabonne/llm-course) | GitHub/YouTube | Self-paced | Phases 6, 12 |
#
# ### Agents & Production
#
# | Course | Platform | Duration | Best For |
# |--------|----------|----------|----------|
# | [LangChain for LLM Application Development](https://www.deeplearning.ai/short-courses/langchain-for-llm-application-development/) | deeplearning.ai | 1h | Phase 15 |
# | [Building and Evaluating Advanced RAG](https://www.deeplearning.ai/short-courses/building-evaluating-advanced-rag/) | deeplearning.ai | 1h | Phase 8 |
# | [AI Agents in LangGraph](https://www.deeplearning.ai/short-courses/ai-agents-in-langgraph/) | deeplearning.ai | 1h | Phase 15 |
# | [Multi AI Agent Systems with CrewAI](https://www.deeplearning.ai/short-courses/multi-ai-agent-systems-with-crewai/) | deeplearning.ai | 1h | Phase 15 |
#
# ---
#
# ## Paid Courses (High Quality)
#
# | Course | Platform | Price Range | Best For |
# |--------|----------|-------------|----------|
# | [Deep Learning Specialization](https://www.coursera.org/specializations/deep-learning) (Andrew Ng) | Coursera | $49/mo | Phases 3, 6 |
# | [Machine Learning Engineering for Production (MLOps)](https://www.coursera.org/specializations/machine-learning-engineering-for-production-mlops) | Coursera | $49/mo | Phase 9 |
# | [LLM Bootcamp](https://fullstackdeeplearning.com/llm-bootcamp/) | Full Stack Deep Learning | Free/Paid | All LLM phases |
# | [Practical AI with Databricks](https://www.udemy.com/) | Udemy | $15–$30 sale | Phase 9 |
#
# > **Tip:** deeplearning.ai short courses are all free to audit (just create an account). Start there before committing to a paid specialization.
#
# ---
#
# ## Video-to-Phase Mapping
#
# | Curriculum Phase | Top Video Resource |
# |------------------|--------------------|
# | Phase 1 (Python) | Sentdex Python playlist |
# | Phase 2 (Data Science) | StatQuest ML fundamentals |
# | Phase 3 (Maths) | 3Blue1Brown linear algebra + calculus |
# | Phase 4 (Tokenization) | Karpathy's minBPE walkthrough |
# | Phase 5 (Embeddings) | Umar Jamil's embedding video |
# | Phase 6 (Neural Networks) | Neural Networks: Zero to Hero (Karpathy) |
# | Phase 8 (RAG) | Sam Witteveen LangChain/RAG playlist |
# | Phase 11 (Prompt Engineering) | deeplearning.ai short courses |
# | Phase 12 (Fine-Tuning) | Sebastian Raschka fine-tuning series |
# | Phase 14 (Local LLMs) | Matthew Berman's Ollama guides |
# | Phase 15 (AI Agents) | Dave Ebbelaar's LangGraph series |
#
# ---
#
# ## How to Use This Guide
#
# 1. Find your current phase in the table above
# 2. Watch the recommended video *before* or *alongside* the notebooks
# 3. Use 1.25–1.5x speed for lecture content, normal speed for coding walkthroughs
# 4. Pause and replicate code in parallel — passive watching is ineffective
#
# **Back to:** [22-references.ipynb](../22-references.ipynb)
