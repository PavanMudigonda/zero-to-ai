# %% [markdown]
# # Learning Roadmaps
#
# > **Status:** Developing — visual curriculum diagrams for the full Zero to AI journey.
# > Browse the notebooks below to orient yourself at any stage of the course.
#
# This folder provides visual roadmaps and curriculum flow diagrams for the entire Zero to AI learning path.
# Use it to see where you are, understand how phases connect, and plan your next steps.
#
# ---
#
# ## How To Use This Folder
#
# - **Orientation**: Open  for the big-picture curriculum flowchart before starting.
# - **During a phase**: Check  to see how your current phase fits into the core ML stack.
# - **Advanced planning**: Use  once you reach Phases 11+.
# - **Project planning**: Use  when designing capstone or portfolio projects.
#
# ---
#
# ## Notebooks in This Section
#
# | # | Notebook | What It Shows |
# |---|----------|---------------|
# | 1 | [](01_overview/01_overview.ipynb) | Full curriculum flow: Foundations → Core ML → Applied AI → Advanced → Production |
# | 2 | [](02_core_systems/02_core_systems.ipynb) | LLM landscape, embeddings, vector search, RAG architecture, agents, multi-agent systems, MLOps |
# | 3 | [](03_advanced_topics/03_advanced_topics.ipynb) | Fine-tuning, RLHF, multimodal, local LLMs, safety, inference optimisation, advanced DL |
# | 4 | [](04_end_to_end_flows/04_end_to_end_flows.ipynb) | End-to-end system flows: data ingestion → processing → serving → monitoring |
#
# ---
#
# ## Curriculum Phases at a Glance
#
# ### Foundation (Phases 00–03)
#  →  →  →
#
# ### Core ML (Phases 04–07)
#  →  →  →
#
# ### Applied AI (Phases 08–10)
#  →  →
#
# ### LLM & Prompt Engineering (Phases 11–14)
#  →  →  →
#
# ### Advanced AI (Phases 15–20)
#  →  →
# →  →  →
#
# ### Reference & Specialised (Phases 21–32)
#  ·  ·  ·
# ·  ·  ·
# ·  ·
# ·  ·  ·
#
# ---
#
# ## Learning Track Recommendations
#
# ### Track A — ML Engineer (fastest to job-ready)
#  →  →  →  →  →  →  →  →  →  →
#
# ### Track B — Data Scientist (statistics + modelling depth)
#  →  →  →  →  →  →  →  →  →  →  →
#
# ### Track C — LLM / GenAI Specialist
#  →  →  →  →  →  →  →  →  →  →
#
# ### Track D — AI Infrastructure / Platform
#  →  →  →  →  →  →  →
#
# ---
#
# ## Prerequisites
#
# None — use this folder at any point for orientation.
#
# ## What Comes Next
#
# After reviewing the roadmaps:
#
# - New learner: Start from [](../00-course-setup/README.md)
# - Mid-curriculum: Return to your current phase and continue
# - Planning a project: Review [](../28-practical-data-science/README.md)
