# %% [markdown]
# # NumPy-Specific Help Functions - Solutions
#
# Exercises on using NumPy's built-in documentation and help utilities.

# %%
import numpy as np

# %%
np.__version__

# %% [markdown]
# Q1. Search for docstrings of the numpy functions on linear algebra.

# %%
np.lookfor('linear algebra')

# %% [markdown]
# Q2. Get help information for numpy dot function.

# %%
np.info(np.dot)
