# %% [markdown]
# # [Chapter 4: Backpropagation Calculus](https://youtu.be/tIeHLnjs5U8?si=6T5qqEjERG5j7uPj)
#
# ## Chain Rule
#
# For f(g(x)): df/dx = f'(g(x)) · g'(x)
#
# Neural networks: MANY nested functions!

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Circle

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (16, 10)
np.random.seed(42)

# %% [markdown]
# ## Computational Graph
#
# Each operation is a node.
#
# Backward pass: multiply gradients along paths.
#
# All gradients computed in one pass!
