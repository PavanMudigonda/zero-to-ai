# %% [markdown]
# # [Chapter 8: How GPT Stores Facts](https://youtu.be/9-Jl0dxWQs8?si=ZxjQWcHfCfczLBWs)
#
# ## Factual Knowledge
#
# GPT knows: 'Paris is the capital of France'
#
# **Where is this stored?**
#
# Distributed across many weights!

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Circle

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (16, 10)
np.random.seed(42)

# %% [markdown]
# ## Mechanistic Interpretability
#
# Facts stored in:
# - **Early layers**: Basic patterns
# - **Middle layers**: Factual associations
# - **Late layers**: Task-specific
#
# Example: 'Michael Jordan plays' → 'basketball'
# Lives in specific attention heads!
