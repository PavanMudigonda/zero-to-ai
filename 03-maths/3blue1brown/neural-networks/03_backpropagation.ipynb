# %% [markdown]
# # [Chapter 3: What is Backpropagation?](https://youtu.be/Ilg3gGewQ5U?si=JTuKCKvVqtFnXwKd)
#
# ## The Challenge
#
# How to compute ∂C/∂w for thousands of weights?
#
# **Answer**: Backpropagation!

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Circle

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (16, 10)
np.random.seed(42)

# %% [markdown]
# ## Intuition
#
# Propagate error backwards through network.
#
# For each weight: How does changing it affect the cost?
#
# This sensitivity IS the gradient.

# %% [markdown]
# ## Chain Rule
#
# Backprop uses the chain rule repeatedly.
#
# Error flows backwards, layer by layer.
