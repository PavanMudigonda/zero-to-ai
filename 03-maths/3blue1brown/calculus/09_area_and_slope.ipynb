# %% [markdown]
# # [Chapter 9: What Does Area Have to Do with Slope?](https://youtu.be/FnJqaIESC2s?si=FmSl6oCd0OOcb1NM)
#
# ## The Fundamental Theorem Explained
#
# Why are derivatives and integrals inverses?
#
# This is the deepest insight in calculus!

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (14, 10)

# %% [markdown]
# The area function A(x) = ∫₀ˣ f(t)dt has derivative A'(x) = f(x)!
