# %% [markdown]
# # [Chapter 6: Understanding the Laplace Transform](https://youtu.be/j0wJBEZdwLs?si=IawfzBOGmmUK1hL7)
#
# ## Geometric Intuition
#
# The Laplace transform wraps a function around a circle in the complex plane.
#
# ### The Process
#
# 1. Take function f(t)
# 2. Multiply by e^(-st)
# 3. Integrate from 0 to ∞
# 4. Get F(s)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (14, 10)
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# ## Applications
#
# - Solving ODEs with initial conditions
# - Circuit analysis
# - Control systems
# - Signal processing
