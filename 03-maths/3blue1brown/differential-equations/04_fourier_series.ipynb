# %% [markdown]
# # [Chapter 4: Fourier Series and Complex Exponential](https://youtu.be/r6sGWTCMz2k?si=eLw-xvvu1BVxL4vC)
#
# ## Decomposing Functions
#
# Any periodic function can be written as a sum of sines and cosines!
#
# $$
# f(x) = \sum_{n=0}^{\infty} [a_n \cos(nx) + b_n \sin(nx)]
# $$
#
# This is a **Fourier series**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (14, 10)
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# ## Complex Exponentials
#
# Euler's formula: e^(iθ) = cos(θ) + i·sin(θ)
#
# This unifies sines and cosines into elegant exponentials!
