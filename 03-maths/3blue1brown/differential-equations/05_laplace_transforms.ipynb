# %% [markdown]
# # [Chapter 5: Laplace Transforms](https://youtu.be/-j8PzkZ70Lg?si=eUIAmI8j9_lxEoDN)
#
# ## A Powerful Tool
#
# The Laplace transform converts differential equations into algebra!
#
# ### Definition
#
# $$
# \mathcal{L}\{f(t)\} = F(s) = \int_0^{\infty} f(t)e^{-st}dt
# $$
#
# Transforms time domain → frequency domain

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (14, 10)
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# ## Why It Works
#
# Derivatives become multiplication:
#
# $$
# \mathcal{L}\left\{\frac{df}{dt}\right\} = sF(s) - f(0)
# $$
#
# This makes solving DEs much easier!
