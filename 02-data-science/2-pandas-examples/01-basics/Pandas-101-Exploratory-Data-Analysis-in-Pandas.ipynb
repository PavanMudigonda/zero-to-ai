# %% [markdown]
# # EDA in Pandas

# %% [markdown]
# Import the libraries needed for this section:
# - **pandas**
# - **seaborn**
# - **matplotlib**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
df = pd.read_csv(r"C:\Users\alexf\OneDrive\Documents\Pandas Tutorial\world_population.csv")
df

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# **DataFrame.info():** Shows column names, data types, non-null counts, and memory usage. Quickly reveals: which columns have missing values, which are the wrong type (e.g., numbers stored as strings), and how much memory the data uses.

# %%
df.info()

# %% [markdown]
# **DataFrame.describe():** Quick statistical summary — count, mean, std, min, max, and quartiles for each numeric column. First thing to run on new data to understand ranges, detect outliers, and check for missing values.

# %%
df.describe()

# %% [markdown]
# Evaluate `df.isnull().sum()` — Jupyter renders the last expression as cell output.

# %%
df.isnull().sum()

# %% [markdown]
# Evaluate `df.nunique()` — Jupyter renders the last expression as cell output.

# %%
df.nunique()

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.
#
# **Sort DataFrame:** Orders rows by one or more columns. Useful for finding top/bottom values, ranking features, and preparing data for sequential analysis.

# %%
df.sort_values(by="World Population Percentage", ascending=False).head(10)

# %% [markdown]
# Evaluate `df.corr()` — Jupyter renders the last expression as cell output.

# %%
df.corr()

# %% [markdown]
# **Heatmap:** A color-coded grid showing the magnitude of values in a 2D matrix. Commonly used for:
# - **Correlation matrices**: Quickly spot which features are related
# - **Confusion matrices**: Visualize classification performance
# - **Attention weights**: See where a Transformer focuses
#
# Annotate with values (`annot=True`) for readability.

# %%
sns.heatmap(df.corr(), annot = True)

plt.rcParams['figure.figsize'] = (20,7)

plt.show()

# %% [markdown]
# **GroupBy — Split-Apply-Combine:** One of the most powerful Pandas operations. It:
# 1. **Splits** the data by one or more keys (categories)
# 2. **Applies** a function to each group independently (mean, sum, count, custom)
# 3. **Combines** the results back into a DataFrame
#
# Example: `df.groupby('city')['price'].mean()` computes the average price per city.

# %%
df.groupby('Continent').mean().sort_values(by="2022 Population",ascending=False)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df[df['Continent'].str.contains('Oceania')]

# %% [markdown]
# **GroupBy — Split-Apply-Combine:** One of the most powerful Pandas operations. It:
# 1. **Splits** the data by one or more keys (categories)
# 2. **Applies** a function to each group independently (mean, sum, count, custom)
# 3. **Combines** the results back into a DataFrame
#
# Example: `df.groupby('city')['price'].mean()` computes the average price per city.

# %%
df2 = df.groupby('Continent')[['1970 Population',
       '1980 Population', '1990 Population', '2000 Population',
       '2010 Population', '2015 Population', '2020 Population',
       '2022 Population']].mean().sort_values(by="2022 Population",ascending=False)
df2

# %% [markdown]
# Evaluate `df.columns` — Jupyter renders the last expression as cell output.

# %%
df.columns

# %% [markdown]
# **Transpose ($A^T$):** Flips a matrix over its diagonal — rows become columns and vice versa. If $A$ is (m×n), then $A^T$ is (n×m).
#
# Properties: $(AB)^T = B^T A^T$, $(A^T)^T = A$. Transpose is fundamental in the Normal Equation and in computing the gradient of matrix expressions.

# %%
df3 = df2.transpose()
df3

# %% [markdown]
# Evaluate `df3.plot()` — Jupyter renders the last expression as cell output.

# %%
df3.plot()

# %% [markdown]
# Evaluate `df.boxplot(figsize=(20,10))` — Jupyter renders the last expression as cell output.

# %%
df.boxplot(figsize=(20,10))

# %% [markdown]
# Evaluate `df.select_dtypes(include='float')` — Jupyter renders the last expression as cell output.

# %%
df.select_dtypes(include='float')
