# %% [markdown]
# # Filtering and Ordering

# %% [markdown]
# Import the libraries needed for this section:
# - **pandas**

# %%
import pandas as pd

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
df = pd.read_csv(r"C:\Users\alexf\OneDrive\Documents\Pandas Tutorial\world_population.csv")

# %% [markdown]
# Evaluate `df` — Jupyter renders the last expression as cell output.

# %%
df

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df[df['Rank'] <= 10]

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
specific_countries = ['Bangladesh','Brazil']

df[df['Country'].isin(specific_countries)]

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df[df['Country'].str.contains('United')]

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df2 = df.set_index('Country')
df2

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df2.filter(items = ['Continent','CCA3'], axis = 1)

# %% [markdown]
# Evaluate `df2.filter(items = ['Zimbabwe'], axis = 0)` — Jupyter renders the last expression as cell output.

# %%
df2.filter(items = ['Zimbabwe'], axis = 0)

# %% [markdown]
# Evaluate `df2.filter(like = 'United', axis = 0)` — Jupyter renders the last expression as cell output.

# %%
df2.filter(like = 'United', axis = 0)

# %% [markdown]
# Access an element or slice using indexing — `df2.loc['United States']`. Python uses zero-based indexing, so the first element is at index 0.

# %%
df2.loc['United States']

# %% [markdown]
# Access an element or slice using indexing — `df2.iloc[3]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
df2.iloc[3]

# %% [markdown]
# **Sort DataFrame:** Orders rows by one or more columns. Useful for finding top/bottom values, ranking features, and preparing data for sequential analysis.

# %%
df[df['Rank'] < 10].sort_values(by=['Continent','Country'],ascending=[False,True])
