# %% [markdown]
# # Indexing

# %% [markdown]
# Import the libraries needed for this section:
# - **pandas**

# %%
import pandas as pd

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
df = pd.read_csv(r"C:\Users\alexf\OneDrive\Documents\Pandas Tutorial\world_population.csv")

df

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
df = pd.read_csv(r"C:\Users\alexf\OneDrive\Documents\Pandas Tutorial\world_population.csv", index_col = "Country")

df

# %% [markdown]
# Evaluate `df.reset_index(inplace=True)` — Jupyter renders the last expression as cell output.

# %%
df.reset_index(inplace=True)

# %% [markdown]
# Evaluate `df` — Jupyter renders the last expression as cell output.

# %%
df

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df.set_index('Country', inplace = True)

df

# %% [markdown]
# Access an element or slice using indexing — `df.loc['Albania']`. Python uses zero-based indexing, so the first element is at index 0.

# %%
df.loc['Albania']

# %% [markdown]
# Access an element or slice using indexing — `df.iloc[1]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
df.iloc[1]

# %% [markdown]
# Evaluate `df.reset_index(inplace = True)` — Jupyter renders the last expression as cell output.

# %%
df.reset_index(inplace = True)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df.set_index(['Continent','Country'], inplace=True)

# %% [markdown]
# pd.set_option('display.max.rows', 235)

# %%
df.sort_index()

#pd.set_option('display.max.rows', 235)

# %% [markdown]
# Access an element or slice using indexing — `df.loc['Africa','Angola']`. Python uses zero-based indexing, so the first element is at index 0.

# %%
df.loc['Africa','Angola']

# %% [markdown]
# Access an element or slice using indexing — `df.iloc[1]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
df.iloc[1]
