# %% [markdown]
# Import the libraries needed for this section:
# - **pandas**
# - **pandas_datareader**
# - **data**

# %%
import pandas as pd
from pandas_datareader import data

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
companies = ["MSFT","GOOG","AAPL","AMZN"]

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
p =data.DataReader(name= companies, data_source="yahoo", start="2010", end="2016")

# %% [markdown]
# Evaluate `p` — Jupyter renders the last expression as cell output.

# %%
p

# %% [markdown]
# Evaluate `p.items` — Jupyter renders the last expression as cell output.

# %%
p.items

# %% [markdown]
# Evaluate `p.major_axis` — Jupyter renders the last expression as cell output.

# %%
p.major_axis

# %% [markdown]
# Evaluate `p.minor_axis` — Jupyter renders the last expression as cell output.

# %%
p.minor_axis

# %% [markdown]
# Evaluate `p.axes` — Jupyter renders the last expression as cell output.

# %%
p.axes

# %% [markdown]
# Evaluate `p.ndin` — Jupyter renders the last expression as cell output.

# %%
p.ndin

# %% [markdown]
# Evaluate `p.dtypes` — Jupyter renders the last expression as cell output.

# %%
p.dtypes

# %% [markdown]
# Evaluate `p.shape` — Jupyter renders the last expression as cell output.

# %%
p.shape

# %% [markdown]
# Evaluate `p.shape` — Jupyter renders the last expression as cell output.

# %%
p.shape

# %% [markdown]
# Evaluate `p.values` — Jupyter renders the last expression as cell output.

# %%
p.values

# %% [markdown]
# Evaluate `p.items` — Jupyter renders the last expression as cell output.

# %%
p.items

# %% [markdown]
# Access an element or slice using indexing — `p["High"]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
p["High"]

# %% [markdown]
# Access an element or slice using indexing — `p['Volume'].head()`. Python uses zero-based indexing, so the first element is at index 0.

# %%
p['Volume'].head()

# %% [markdown]
# Evaluate `p.Close` — Jupyter renders the last expression as cell output.

# %%
p.Close

# %% [markdown]
# Access an element or slice using indexing — `p.loc["Close","2010-01-04","GOOG"]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
p.loc["Close","2010-01-04","GOOG"]

# %% [markdown]
# Access an element or slice using indexing — `p.iloc[4,200]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
p.iloc[4,200]

# %% [markdown]
# Access an element or slice using indexing — `p.iloc[4,200,2]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
p.iloc[4,200,2]

# %% [markdown]
# Evaluate `p.to_frame()` — Jupyter renders the last expression as cell output.

# %%
p.to_frame()

# %% [markdown]
# Evaluate `p.items` — Jupyter renders the last expression as cell output.

# %%
p.items

# %% [markdown]
# Evaluate `p.major_axis` — Jupyter renders the last expression as cell output.

# %%
p.major_axis

# %% [markdown]
# Evaluate `p.major_xs("2015-12-31")` — Jupyter renders the last expression as cell output.

# %%
p.major_xs("2015-12-31")

# %% [markdown]
# Evaluate `p` — Jupyter renders the last expression as cell output.

# %%
p

# %% [markdown]
# Evaluate `p.minor_axis` — Jupyter renders the last expression as cell output.

# %%
p.minor_axis

# %% [markdown]
# Evaluate `p.minor_xs('AAPL')` — Jupyter renders the last expression as cell output.

# %%
p.minor_xs('AAPL')

# %% [markdown]
# Evaluate `p.axes` — Jupyter renders the last expression as cell output.

# %%
p.axes

# %% [markdown]
# **Transpose ($A^T$):** Flips a matrix over its diagonal — rows become columns and vice versa. If $A$ is (m×n), then $A^T$ is (n×m).
#
# Properties: $(AB)^T = B^T A^T$, $(A^T)^T = A$. Transpose is fundamental in the Normal Equation and in computing the gradient of matrix expressions.

# %%
p2 = p.transpose(2,1,0)

# %% [markdown]
# Evaluate `p2` — Jupyter renders the last expression as cell output.

# %%
p2

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
p2.major_axis

p.major_axis

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
p2.minor_axis

p.minor_axis

# %% [markdown]
# Access an element or slice using indexing — `p2['GOOG']`. Python uses zero-based indexing, so the first element is at index 0.

# %%
p2['GOOG']

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
p2 = p.swapaxes("items","minor")

# %% [markdown]
# Evaluate `p2` — Jupyter renders the last expression as cell output.

# %%
p2

# %% [markdown]
# Access an element or slice using indexing — `p2['MSFT']`. Python uses zero-based indexing, so the first element is at index 0.

# %%
p2['MSFT']
