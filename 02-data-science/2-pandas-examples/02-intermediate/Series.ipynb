# %% [markdown]
# Create series in python

# %% [markdown]
# Import the libraries needed for this section:
# - **pandas**

# %%
import pandas as pd
ice_cream = ['vanilla','chocolate','mousse','rocky road']

# %% [markdown]
# Evaluate `pd.Series(ice_cream)` — Jupyter renders the last expression as cell output.

# %%
pd.Series(ice_cream)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
lottery = [1,2,8,4,5,22,8,9]
pd.Series(lottery)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
registration = [True, False, False, True, True, True]
pd.Series(registration)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
merriam = {"Work":"Office","Play":"Stadium","Study":"Class"}
pd.Series(merriam)

# %% [markdown]
# ### Intro to Attributes
#
# The code below implements this step in the Pandas data manipulation workflow.

# %%
## Intro to Attributes

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
about_me = ["Yo","Yep","thats","awesomwe"]
s = pd.Series(about_me)
s

# %% [markdown]
# Evaluate `s.values` — Jupyter renders the last expression as cell output.

# %%
s.values

# %% [markdown]
# Evaluate `s.index` — Jupyter renders the last expression as cell output.

# %%
s.index

# %% [markdown]
# Evaluate `s.dtype` — Jupyter renders the last expression as cell output.

# %%
s.dtype

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
prices = [1.44,6.8,9.65]
s = pd.Series(prices)
s

# %% [markdown]
# Evaluate `s.sum()` — Jupyter renders the last expression as cell output.

# %%
s.sum()

# %% [markdown]
# Evaluate `s.mean()` — Jupyter renders the last expression as cell output.

# %%
s.mean()
