# %% [markdown]
# Import the libraries needed for this section:
# - **pandas**

# %%
import pandas as pd
fruit = ['apple','orange','mango','strawberry','blueberry']
weekdays = ['Sun','Mon','Tue','Wed','Thur']

# %% [markdown]
# Evaluate `pd.Series(fruit,weekdays)` — Jupyter renders the last expression as cell output.

# %%
pd.Series(fruit,weekdays)
