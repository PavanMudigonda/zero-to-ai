# %% [markdown]
# Import the libraries needed for this section:
# - **pandas**

# %%
import pandas as pd

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"] )
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
df.head()
output = None

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
output = None

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df["Start Date"]
outpput = None

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"])

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df["Senior Management"] = df["Senior Management"].astype("bool")

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df["Gender"] = df["Gender"].astype("category")

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
output = None

# %% [markdown]
# Evaluate `df` — Jupyter renders the last expression as cell output.

# %%
df

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df[df["Gender"] == "Male"]

# %% [markdown]
# Access an element or slice using indexing — `df["team"]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
df["team"]

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df[df["Team"].isin(["Marketing","Legal"])]

# %% [markdown]
# **Sort DataFrame:** Orders rows by one or more columns. Useful for finding top/bottom values, ranking features, and preparing data for sequential analysis.

# %%
df.sort_values("First Name", inplace = True)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
mask = ~df["First Name"].duplicated(keep = False)

# %% [markdown]
# Access an element or slice using indexing — `df[mask]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
df[mask]

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
len(df.drop_duplicates(subset = "First Name", keep = False))

# %% [markdown]
# Access an element or slice using indexing — `df["Gender"].unique()`. Python uses zero-based indexing, so the first element is at index 0.

# %%
df["Gender"].unique()

# %% [markdown]
# Access an element or slice using indexing — `df["Team"].unique()`. Python uses zero-based indexing, so the first element is at index 0.

# %%
df["Team"].unique()

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df["Team"].nunique(dropna= False)
