# %% [markdown]
# Import the libraries needed for this section:
# - **pandas**

# %%
import pandas as pd

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"])
bigmac.head()

# %% [markdown]
# Evaluate `bigmac.dtypes` — Jupyter renders the last expression as cell output.

# %%
bigmac.dtypes

# %% [markdown]
# **DataFrame.info():** Shows column names, data types, non-null counts, and memory usage. Quickly reveals: which columns have missing values, which are the wrong type (e.g., numbers stored as strings), and how much memory the data uses.

# %%
bigmac.info()

# %% [markdown]
# Access an element or slice using indexing — `bigmac["Country"].nunique()`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bigmac["Country"].nunique()

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
bigmac["Country"] = bigmac["Country"].astype("category")

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
bigmac.set_index(keys = ["Date","Country"], inplace=True)

# %% [markdown]
# Evaluate `bigmac.sort_index(inplace=True)` — Jupyter renders the last expression as cell output.

# %%
bigmac.sort_index(inplace=True)

# %% [markdown]
# Evaluate `bigmac.index.names` — Jupyter renders the last expression as cell output.

# %%
bigmac.index.names

# %% [markdown]
# Evaluate `type(bigmac.index)` — Jupyter renders the last expression as cell output.

# %%
type(bigmac.index)

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date","Country"])
bigmac.sort_index(inplace=True)
bigmac.head()

# %% [markdown]
# Evaluate `bigmac.index.get_level_values(0)` — Jupyter renders the last expression as cell output.

# %%
bigmac.index.get_level_values(0)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
bigmac.index.set_names(["Date","Country"], inplace=True)

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
bigmac.head()

# %% [markdown]
# Evaluate `bigmac.sort_index(ascending=[True,False])` — Jupyter renders the last expression as cell output.

# %%
bigmac.sort_index(ascending=[True,False])

# %% [markdown]
# **DataFrame Indexing:** Access specific rows/columns:
# - `.iloc[row, col]`: integer-based (position)
# - `.loc[label, col]`: label-based (index values)
# - `.drop()`: remove rows/columns by label

# %%
bigmac.loc[("2010-01-01","Norway"),"Price in US Dollars"]

# %% [markdown]
# **Transpose ($A^T$):** Flips a matrix over its diagonal — rows become columns and vice versa. If $A$ is (m×n), then $A^T$ is (n×m).
#
# Properties: $(AB)^T = B^T A^T$, $(A^T)^T = A$. Transpose is fundamental in the Normal Equation and in computing the gradient of matrix expressions.
#
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
bigmac.transpose()

bigmac.head()

# %% [markdown]
# Access an element or slice using indexing — `bigmac.ix["Price in US Dollars"]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bigmac.ix["Price in US Dollars"]

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date","Country"])
bigmac.sort_index(inplace=True)
bigmac.head()

# %% [markdown]
# Evaluate `bigmac.swaplevel()` — Jupyter renders the last expression as cell output.

# %%
bigmac.swaplevel()

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
world = pd.read_csv("worldstats.csv", index_col=["country","year"])
world.head()

# %% [markdown]
# Evaluate `world.stack()` — Jupyter renders the last expression as cell output.

# %%
world.stack()

# %% [markdown]
# **DataFrame.info():** Shows column names, data types, non-null counts, and memory usage. Quickly reveals: which columns have missing values, which are the wrong type (e.g., numbers stored as strings), and how much memory the data uses.

# %%
world.info()

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
world.head()

# %% [markdown]
# Evaluate `type(world.stack().to_frame())` — Jupyter renders the last expression as cell output.

# %%
type(world.stack().to_frame())

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
s = world.stack()

# %% [markdown]
# Evaluate `s.unstack()` — Jupyter renders the last expression as cell output.

# %%
s.unstack()

# %% [markdown]
# Evaluate `s.unstack().unstack().unstack()` — Jupyter renders the last expression as cell output.

# %%
s.unstack().unstack().unstack()

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
s.unstack(2)
s.unstack("year")

# %% [markdown]
# Evaluate `s.unstack(level = ["country","year"])` — Jupyter renders the last expression as cell output.

# %%
s.unstack(level = ["country","year"])

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
t = s.unstack(level = ["year"], fill_value = 0)

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
t.head()

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
sales = pd.read_csv("salesmen.csv", parse_dates = ["Date"])
sales["Salesman"] = sales["Salesman"].astype("category")

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
sales.head()

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
sales.pivot(index="Date", columns="Salesman", values="Revenue")

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
foods = pd.read_csv("foods.csv")
foods.head()

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
foods.pivot_table(values="Spend", index=["Gender","Item"], columns="City", aggfunc="sum")

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
sales = pd.read_csv("quarters.csv")
sales.head()

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
sales.melt(id_vars="Salesman",var_name="Quater", value_name="Revenue")
