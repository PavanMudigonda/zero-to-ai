# %% [markdown]
# Import the libraries needed for this section:
# - **pandas**
# - **datetime**

# %%
import pandas as pd
import datetime as dt

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
someday = dt.date(2018,4,14)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
someday.year
someday.month
someday.day

# %% [markdown]
# Evaluate `str(dt.datetime(2018,4,14,8,50,44))` — Jupyter renders the last expression as cell output.

# %%
str(dt.datetime(2018,4,14,8,50,44))

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
sometime =dt.datetime(2018,4,14,8,50,44)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
sometime.day
sometime.month
sometime.year
sometime.hour
sometime.minute

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
pd.Timestamp('2015-1-6')
pd.Timestamp('2015/1/6')
pd.Timestamp('1/6/2015')
pd.Timestamp('12/19/2015')
pd.Timestamp('19/12/2015')

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
dates = ['2015-1-6','2015-5-6','2015-2-2']
dtIndex = pd.DatetimeIndex(dates)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
values= [100,200,400]

# %% [markdown]
# Evaluate `pd.Series(data = values , index=dtIndex)` — Jupyter renders the last expression as cell output.

# %%
pd.Series(data = values , index=dtIndex)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
times = pd.date_range(start='2016', end='2018',freq='D')

# %% [markdown]
# Access an element or slice using indexing — `type(times[0])`. Python uses zero-based indexing, so the first element is at index 0.

# %%
type(times[0])

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
times = pd.date_range(start='2016', end='2018',freq='w')

# %% [markdown]
# Evaluate `times` — Jupyter renders the last expression as cell output.

# %%
times

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
pd.date_range(start='2016', end='2018',freq='w-FRI')

# %% [markdown]
# Evaluate `pd.date_range(start='2016', end='2018',freq='5H')` — Jupyter renders the last expression as cell output.

# %%
pd.date_range(start='2016', end='2018',freq='5H')

# %% [markdown]
# Evaluate `pd.date_range(start='2016', end='2018',freq='M')` — Jupyter renders the last expression as cell output.

# %%
pd.date_range(start='2016', end='2018',freq='M')

# %% [markdown]
# Evaluate `pd.date_range(start='2016', end='2018',freq='A')` — Jupyter renders the last expression as cell output.

# %%
pd.date_range(start='2016', end='2018',freq='A')

# %% [markdown]
# Evaluate `pd.date_range(start='2014', periods=25)` — Jupyter renders the last expression as cell output.

# %%
pd.date_range(start='2014', periods=25)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
bunch_of_dates = pd.date_range(start='2000',end='2016', freq='2D')

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
a = pd.Series(bunch_of_dates)

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
a.head()

# %% [markdown]
# Evaluate `a.dt.day` — Jupyter renders the last expression as cell output.

# %%
a.dt.day

# %% [markdown]
# Evaluate `a.dt.weekday_name` — Jupyter renders the last expression as cell output.

# %%
a.dt.weekday_name

# %% [markdown]
# Import the libraries needed for this section:
# - **pandas_datareader**
# - **data**

# %%
from pandas_datareader import data

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
company = "MSFT"
start =  "2010-01-01"
end = "2016-12-12"

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
stocks = data.DataReader(name = company,data_source="yahoo",start = start, end = end)

# %% [markdown]
# **DataFrame Indexing:** Access specific rows/columns:
# - `.iloc[row, col]`: integer-based (position)
# - `.loc[label, col]`: label-based (index values)
# - `.drop()`: remove rows/columns by label

# %%
stocks.loc['2014-04-01']
stocks.iloc[299]

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
birthday = pd.date_range(start='2000-04-01', end='2016-04-01', freq=pd.DateOffset(years=1))

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
mask = stocks.index.isin(birthday)

# %% [markdown]
# Access an element or slice using indexing — `stocks.loc[mask]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
stocks.loc[mask]

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
stocks.insert(0,"Day of the Week",stocks.index.weekday_name)

stocks.insert(1,"Week Day",stocks.index.weekday_namee)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
someday = stocks.index[299]

# %% [markdown]
# Evaluate `someday.weekday_name` — Jupyter renders the last expression as cell output.

# %%
someday.weekday_name

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
stocks.head()

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
stocks.insert(1,"Week Day",stocks.index.weekday_name)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
stocks.truncate(before="2009-12-31", after="2011-12-31")

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
stocks.index + pd.DateOffset(months = 4)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
stocks.index+ pd.tseries.offsets.MonthEnd()

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
timeA = pd.Timestamp('2010-01-31')
timeB = pd.Timestamp('2016-01-31')

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
timeA - timeB

# %% [markdown]
# Evaluate `type(timeA - timeB)` — Jupyter renders the last expression as cell output.

# %%
type(timeA - timeB)

# %% [markdown]
# Evaluate `pd.Timedelta(days = 4, weeks = 8, hours = 12)` — Jupyter renders the last expression as cell output.

# %%
pd.Timedelta(days = 4, weeks = 8, hours = 12)

# %% [markdown]
# Evaluate `pd.Timedelta("6 hours 12 minutes")` — Jupyter renders the last expression as cell output.

# %%
pd.Timedelta("6 hours 12 minutes")

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
shipping = pd.read_csv('ecommerce.csv', index_col='ID', parse_dates=['order_date','delivery_date'])

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
shipping['delivery_time'] = shipping['delivery_date'] - shipping['order_date']

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
shipping.head()

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
mask = shipping['delivery_time'] > '256 days'
shipping[mask]
