# %% [markdown]
# Import the libraries needed for this section:
# - **pandas**

# %%
import pandas as pd

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
t = pd.read_csv("https://data.cityofnewyork.us/api/views/ic3t-wcy2/rows.csv").head()

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
pd.read_csv("https://data.cityofnewyork.us/api/views/ic3t-wcy2/rows.csv").head(2)

# %% [markdown]
# Evaluate `t.to_csv("test_Export.csv")` — Jupyter renders the last expression as cell output.

# %%
t.to_csv("test_Export.csv")

# %% [markdown]
# Evaluate `t.to_csv("test_Export.csv",index=False)` — Jupyter renders the last expression as cell output.

# %%
t.to_csv("test_Export.csv",index=False)

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
crime_india = pd.read_csv("https://data.gov.in/node/4223881/datastore/export/csv")

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
crime_india.to_csv("crime_india.csv",index=False,encoding="UTF8")

# %% [markdown]
# Evaluate `pd.read_excel("Data - Multiple Worksheets.xlsx")` — Jupyter renders the last expression as cell output.

# %%
pd.read_excel("Data - Multiple Worksheets.xlsx")

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
pd.read_excel("Data - Multiple Worksheets.xlsx", sheetname=1)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
pd.read_excel("Data - Multiple Worksheets.xlsx", sheetname=[0,1])

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
state = crime_india["State/UT (Col.3)"]

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
excel_file = pd.ExcelWriter("State Name.xlsx")

# %% [markdown]
# Evaluate `state.to_excel(excel_file,index=False)` — Jupyter renders the last expression as cell output.

# %%
state.to_excel(excel_file,index=False)

# %% [markdown]
# Evaluate `excel_file.save()` — Jupyter renders the last expression as cell output.

# %%
excel_file.save()
