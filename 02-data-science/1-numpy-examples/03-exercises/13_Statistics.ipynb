# %% [markdown]
# # Statistics

# %% [markdown]
# The code below implements the next step in this statistics workflow. See the inline comments for details on each operation.

# %%
__author__ = "kyubyong. kbpark.linguist@gmail.com"

# %% [markdown]
# Import the libraries needed for this section:
# - **numpy**

# %%
import numpy as np

# %% [markdown]
# Evaluate `np.__version__` — Jupyter renders the last expression as cell output.

# %%
np.__version__

# %% [markdown]
# ## Order statistics

# %% [markdown]
# Q1. Return the minimum value of x along the second axis.

# %%
x = np.arange(4).reshape((2, 2))
print("x=\n", x)

# %% [markdown]
# Q2. Return the maximum value of x along the second axis. Reduce the second axis to the dimension with size one.

# %%
x = np.arange(4).reshape((2, 2))
print("x=\n", x)

# %% [markdown]
# Q3. Calcuate the difference between the maximum and the minimum of x along the second axis.

# %%
x = np.arange(10).reshape((2, 5))
print("x=\n", x)

# %% [markdown]
# Q4. Compute the 75th percentile of x along the second axis.

# %%
x = np.arange(1, 11).reshape((2, 5))
print("x=\n", x)

# %% [markdown]
# ## Averages and variances

# %% [markdown]
# Q5. Compute the median of flattened x.

# %% [markdown]
# Run this cell and inspect the output to verify the statistics operations produce the expected results.

# %%
x = np.arange(1, 10).reshape((3, 3))
print("x=\n", x)

# %% [markdown]
# Q6. Compute the weighted average of x.

# %% [markdown]
# The code below implements the next step in this statistics workflow. See the inline comments for details on each operation.

# %%
x = np.arange(5)
weights = np.arange(1, 6)

# %% [markdown]
# Q7. Compute the mean, standard deviation, and variance of x along the second axis.

# %%
x = np.arange(5)
print("x=\n",x)

# %% [markdown]
# ## Correlating

# %% [markdown]
# Q8. Compute the covariance matrix of x and y.

# %% [markdown]
# The code below implements the next step in this statistics workflow. See the inline comments for details on each operation.

# %%
x = np.array([0, 1, 2])
y = np.array([2, 1, 0])

# %% [markdown]
# Q9. In the above covariance matrix, what does the -1 mean?

# %% [markdown]
# Q10. Compute Pearson product-moment correlation coefficients of x and y.

# %%
x = np.array([0, 1, 3])
y = np.array([2, 4, 5])

# %% [markdown]
# Q11. Compute cross-correlation of x and y.

# %% [markdown]
# The code below implements the next step in this statistics workflow. See the inline comments for details on each operation.

# %%
x = np.array([0, 1, 3])
y = np.array([2, 4, 5])

# %% [markdown]
# ## Histograms

# %% [markdown]
# Q12. Compute the histogram of x against the bins.

# %% [markdown]
# **Histogram:** Shows the distribution of a single variable by dividing values into bins and counting how many fall in each. Reveals the shape of the data: normal, skewed, bimodal, uniform, etc.
#
# Always check distributions before modeling — many algorithms assume normally distributed features.

# %%
x = np.array([0.5, 0.7, 1.0, 1.2, 1.3, 2.1])
bins = np.array([0, 1, 2, 3])
print("ans=\n", ...)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist(x, bins=bins)
plt.show()

# %% [markdown]
# Q13. Compute the 2d histogram of x and y.

# %% [markdown]
# **Scatter Plot:** Displays individual data points as dots on a 2D plane. Each point's position is determined by its x and y values. Color and size can encode additional dimensions.
#
# **Use for:** Exploring relationships between two continuous variables, spotting clusters, identifying outliers, and visualizing model predictions vs. actual values.

# %%
xedges = [0, 1, 2, 3]
yedges = [0, 1, 2, 3, 4]
x = np.array([0, 0.1, 0.2, 1., 1.1, 2., 2.1])
y = np.array([0, 0.1, 0.2, 1., 1.1, 2., 3.3])
...

plt.scatter(x, y)
plt.grid()

# %% [markdown]
# Q14. Count number of occurrences of 0 through 7 in x.

# %%
x = np.array([0, 1, 1, 3, 2, 1, 7])

# %% [markdown]
# Q15. Return the indices of the bins to which each value in x belongs.

# %%
x = np.array([0.2, 6.4, 3.0, 1.6])
bins = np.array([0.0, 1.0, 2.5, 4.0, 10.0])
