# %% [markdown]
# # Mathematical Functions -- Solutions
#
# Solutions for NumPy's comprehensive mathematical function library, covering trigonometry, hyperbolic functions, rounding, aggregation (sums/products/differences), exponents, logarithms, floating-point routines, arithmetic operations, and miscellaneous utilities like `np.clip()`, `np.square()`, `np.sqrt()`, and `np.sign()`.

# %%
import numpy as np

# %%
np.__version__

# %%
__author__ = "kyubyong. kbpark.linguist@gmail.com. https://github.com/kyubyong"

# %% [markdown]
# ## Trigonometric Functions
#
# Solutions using `np.sin()`, `np.cos()`, `np.tan()`, `np.arcsin()`, `np.arccos()`, `np.arctan()`, `np.degrees()`, `np.radians()`, and their aliases.

# %% [markdown]
# Q1. Calculate sine, cosine, and tangent of x, element-wise.

# %%
x = np.array([0., 1., 30, 90])
print("sine:", np.sin(x))
print("cosine:", np.cos(x))
print("tangent:", np.tan(x))

# %% [markdown]
# Q2. Calculate inverse sine, inverse cosine, and inverse tangent of x, element-wise.

# %%
x = np.array([-1., 0, 1.])
print("inverse sine:", np.arcsin(x2))
print("inverse cosine:", np.arccos(x2))
print("inverse tangent:", np.arctan(x2))

# %% [markdown]
# Q3. Convert angles from radians to degrees.

# %%
x = np.array([-np.pi, -np.pi/2, np.pi/2, np.pi])

out1 = np.degrees(x)
out2 = np.rad2deg(x)
assert np.array_equiv(out1, out2)
print(out1)

# %% [markdown]
# Q4. Convert angles from degrees to radians.

# %%
x = np.array([-180.,  -90.,   90.,  180.])

out1 = np.radians(x)
out2 = np.deg2rad(x)
assert np.array_equiv(out1, out2)
print(out1)

# %% [markdown]
# ## Hyperbolic Functions
#
# Solutions using `np.sinh()`, `np.cosh()`, and `np.tanh()` for hyperbolic function computation.

# %% [markdown]
# Q5. Calculate hyperbolic sine, hyperbolic cosine, and hyperbolic tangent of x, element-wise.

# %%
x = np.array([-1., 0, 1.])
print(np.sinh(x))
print(np.cosh(x))
print(np.tanh(x))

# %% [markdown]
# ## Rounding
#
# Solutions comparing `np.around()`, `np.floor()`, `np.ceil()`, `np.trunc()`, and Python's built-in `round()` -- note the subtle differences in rounding behavior.

# %% [markdown]
# Q6. Predict the results of these, paying attention to the difference among the family functions.

# %%
x = np.array([2.1, 1.5, 2.5, 2.9, -2.1, -2.5, -2.9])

out1 = np.around(x)
out2 = np.floor(x)
out3 = np.ceil(x)
out4 = np.trunc(x)
out5 = [round(elem) for elem in x]

print(out1)
print(out2)
print(out3)
print(out4)
print(out5)

# %% [markdown]
# Q7. Implement out5 in the above question using numpy.

# %%
print(np.floor(np.abs(x) + 0.5) * np.sign(x))
# Read http://numpy-discussion.10968.n7.nabble.com/why-numpy-round-get-a-different-result-from-python-round-function-td19098.html

# %% [markdown]
# ## Sums, Products, Differences
#
# Solutions using `np.sum()`, `np.prod()`, `np.cumsum()`, `np.cumprod()`, `np.diff()`, `np.ediff1d()`, `np.cross()`, `np.min()`, `np.max()`, and `np.mean()` with various `axis` and `keepdims` configurations.

# %% [markdown]
# Q8. Predict the results of these.

# %%
x = np.array(
    [[1, 2, 3, 4],
     [5, 6, 7, 8]])

outs = [np.sum(x),
        np.sum(x, axis=0),
        np.sum(x, axis=1, keepdims=True),
        "",
        np.prod(x),
        np.prod(x, axis=0),
        np.prod(x, axis=1, keepdims=True),
        "",
        np.cumsum(x),
        np.cumsum(x, axis=0),
        np.cumsum(x, axis=1),
        "",
        np.cumprod(x),
        np.cumprod(x, axis=0),
        np.cumprod(x, axis=1),
        "",
        np.min(x),
        np.min(x, axis=0),
        np.min(x, axis=1, keepdims=True),
        "",
        np.max(x),
        np.max(x, axis=0),
        np.max(x, axis=1, keepdims=True),
        "",
        np.mean(x),
        np.mean(x, axis=0),
        np.mean(x, axis=1, keepdims=True)]
           
for out in outs:
    if out == "":
        print(else:)
        print("->", out)

# %% [markdown]
# Q9. Calculate the difference between neighboring elements, element-wise.

# %%
x = np.array([1, 2, 4, 7, 0])
print(np.diff(x))

# %% [markdown]
# Q10. Calculate the difference between neighboring elements, element-wise, and
# prepend [0, 0] and append[100] to it.

# %%
x = np.array([1, 2, 4, 7, 0])

out1 = np.ediff1d(x, to_begin=[0, 0], to_end=[100])
out2 = np.insert(np.append(np.diff(x), 100), 0, [0, 0])
assert np.array_equiv(out1, out2)
print(out2)

# %% [markdown]
# Q11. Return the cross product of x and y.

# %%
x = np.array([1, 2, 3])
y = np.array([4, 5, 6])

print(np.cross(x, y))

# %% [markdown]
# ## Exponents and Logarithms
#
# Solutions using `np.exp()`, `np.expm1()`, `np.exp2()`, `np.log()`, `np.log2()`, `np.log10()`, and `np.log1p()` for exponential and logarithmic computation.

# %% [markdown]
# Q12. Compute $e^x$, element-wise.

# %%
x = np.array([1., 2., 3.], np.float32)

out = np.exp(x)
print(out)

# %% [markdown]
# Q13. Calculate exp(x) - 1 for all elements in x.

# %%
x = np.array([1., 2., 3.], np.float32)

out1 = np.expm1(x)
out2 = np.exp(x) - 1.
assert np.allclose(out1, out2)
print(out1)

# %% [markdown]
# Q14. Calculate $2^p$ for all p in x.

# %%
x = np.array([1., 2., 3.], np.float32)

out1 = np.exp2(x)
out2 = 2 ** x
assert np.allclose(out1, out2)
print(out1)

# %% [markdown]
# Q15. Compute natural, base 10, and base 2 logarithms of x element-wise.

# %%
x = np.array([1, np.e, np.e**2])

print("natural log =", np.log(x))
print("common log =", np.log10(x))
print("base 2 log =", np.log2(x))

# %% [markdown]
# Q16. Compute the natural logarithm of one plus each element in x in floating-point accuracy.

# %%
x = np.array([1e-99, 1e-100])

print(np.log1p(x))
# Compare it with np.log(1 +x)

# %% [markdown]
# ## Floating Point Routines
#
# Solutions using `np.signbit()` and `np.copysign()` for sign-related floating-point operations.

# %% [markdown]
# Q17. Return element-wise True where signbit is set.

# %%
x = np.array([-3, -2, -1, 0, 1, 2, 3])

out1 = np.signbit(x)
out2 = x < 0
assert np.array_equiv(out1, out2)
print(out1)

# %% [markdown]
# Q18. Change the sign of x to that of y, element-wise.

# %%
x = np.array([-1, 0, 1])
y = -1.1

print(np.copysign(x, y))

# %% [markdown]
# ## Arithmetic Operations
#
# Solutions using `np.add()`, `np.subtract()`, `np.multiply()`, `np.true_divide()`, `np.floor_divide()`, `np.negative()`, `np.reciprocal()`, `np.power()`, `np.mod()`, and `np.fmod()` -- each shown alongside its operator equivalent.

# %% [markdown]
# Q19. Add x and y element-wise.

# %%
x = np.array([1, 2, 3])
y = np.array([-1, -2, -3])

out1 = np.add(x, y)
out2 = x + y
assert np.array_equal(out1, out2)
print(out1)

# %% [markdown]
# Q20. Subtract y from x element-wise.

# %%
x = np.array([3, 4, 5])
y = np.array(3)

out1 = np.subtract(x, y)
out2 = x - y 
assert np.array_equal(out1, out2)
print(out1)

# %% [markdown]
# Q21. Multiply x by y element-wise.

# %%
x = np.array([3, 4, 5])
y = np.array([1, 0, -1])

out1 = np.multiply(x, y)
out2 = x * y 
assert np.array_equal(out1, out2)
print(out1)

# %% [markdown]
# Q22. Divide x by y element-wise in two different ways.

# %%
x = np.array([3., 4., 5.])
y = np.array([1., 2., 3.])

out1 = np.true_divide(x, y)
out2 = x / y 
assert np.array_equal(out1, out2)
print(out1)

out3 = np.floor_divide(x, y)
out4 = x // y
assert np.array_equal(out3, out4)
print(out3)

# Note that in Python 2 and 3, the handling of `divide` differs.
# See https://docs.scipy.org/doc/numpy/reference/generated/numpy.divide.html#numpy.divide

# %% [markdown]
# Q23. Compute numerical negative value of x, element-wise.

# %%
x = np.array([1, -1])

out1 = np.negative(x)
out2 = -x
assert np.array_equal(out1, out2)
print(out1)

# %% [markdown]
# Q24. Compute the reciprocal of x, element-wise.

# %%
x = np.array([1., 2., .2])

out1 = np.reciprocal(x)
out2 = 1/x
assert np.array_equal(out1, out2)
print(out1)

# %% [markdown]
# Q25. Compute $x^y$, element-wise.

# %%
x = np.array([[1, 2], [3, 4]])
y = np.array([[1, 2], [1, 2]])

out = np.power(x, y)
print(out)

# %% [markdown]
# Q26. Compute the remainder of x / y element-wise in two different ways.

# %%
x = np.array([-3, -2, -1, 1, 2, 3])
y = 2

out1 = np.mod(x, y)
out2 = x % y
assert np.array_equal(out1, out2)
print(out1)

out3 = np.fmod(x, y)
print(out3)

# %% [markdown]
# ## Miscellaneous
#
# Solutions using `np.clip()`, `np.square()`, `np.sqrt()`, `np.abs()`, and `np.sign()` for common mathematical utilities.

# %% [markdown]
# Q27. If an element of x is smaller than 3, replace it with 3.
# And if an element of x is bigger than 7, replace it with 7.

# %%
x = np.arange(10)

out1 = np.clip(x, 3, 7)
out2 = np.copy(x)
out2[out2 < 3] = 3
out2[out2 > 7] = 7

assert np.array_equiv(out1, out2)
print(out1)

# %% [markdown]
# Q28. Compute the square of x, element-wise.

# %%
x = np.array([1, 2, -1])

out1 = np.square(x)
out2 = x * x
assert np.array_equal(out1, out2)
print(out1)

# %% [markdown]
# Q29. Compute square root of x element-wise.

# %%
x = np.array([1., 4., 9.])

out = np.sqrt(x)
print(out)

# %% [markdown]
# Q30. Compute the absolute value of x.

# %%
x = np.array([[1, -1], [3, -3]])

out = np.abs(x)
print(out)

# %% [markdown]
# Q31. Compute an element-wise indication of the sign of x, element-wise.

# %%
x = np.array([1, 3, 0, -1, -3])

out1 = np.sign(x)
out2 = np.copy(x)
out2[out2 > 0] = 1
out2[out2 < 0] = -1
assert np.array_equal(out1, out2)
print(out1)
