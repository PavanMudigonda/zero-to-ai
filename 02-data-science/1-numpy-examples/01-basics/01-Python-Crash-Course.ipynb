# %% [markdown]
# ## Data types
#
# ### Numbers

# %%
1 + 1

# %% [markdown]
# **Python Multiplication:** `1 * 3` — Jupyter displays the last expression's value automatically.

# %%
1 * 3

# %% [markdown]
# **Python Division:** `1 / 2` — Jupyter displays the last expression's value automatically.

# %%
1 / 2

# %% [markdown]
# ** is raised to that power - thus this is 2 to the power of 4

# %%
2 ** 4

# %% [markdown]
# % is used as "mod" or "modulus" - shows what remainders after division

# %%
4 % 2

# %% [markdown]
# **Python Modulo (Remainder):** Evaluate `5 % 2`. In Jupyter, the last expression in a cell is automatically displayed as output without needing `print()`.

# %%
5 % 2

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
(2 + 3) * (5 + 5)

# %% [markdown]
# ### Variable Assignment

# %% [markdown]
# Can not start with number or special characters

# %%
# Can not start with number or special characters
name_of_var = 2

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
x = 2
y = 3

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
z = x + y

# %% [markdown]
# Evaluate `z` — Jupyter renders the last expression as cell output.

# %%
z

# %% [markdown]
# ### Strings

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
'single quotes'

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
"double quotes"

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
" wrap lot's of other quotes"

# %% [markdown]
# ### Printing

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
x = 'hello'

# %% [markdown]
# If you don't pass to the print() function - shows this way with quotes to show it's a string

# %%
x

# %% [markdown]
# Evaluate `print(x)` — Jupyter renders the last expression as cell output.

# %%
print(x)

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
num = 12
name = 'Sam'

# %% [markdown]
# Don't believe this is correct now - python 3.7 use f"ejowiefj" format

# %%
print('My number is: {one}, and my name is: {two}'.format(one=num,two=name))

# %% [markdown]
# Run this cell and inspect the output to verify the NumPy operations produce the expected results.

# %%
print('My number is: {}, and my name is: {}'.format(num,name))

# %% [markdown]
# Updated way to run - tested 6/14/2023

# %% [markdown]
# Run this cell and inspect the output to verify the NumPy operations produce the expected results.

# %%
print(f"My number is: {num}, and my name is {name}")

# %% [markdown]
# To grab index of string

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
s = 'abcdefghijkl'

# %% [markdown]
# Access an element or slice using indexing — `s[2]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
s[2]

# %% [markdown]
# To grab slice - up to but not including number

# %% [markdown]
# Access an element or slice using indexing — `s[:3]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
s[:3]

# %% [markdown]
# slice the other way around - from index and beyond

# %% [markdown]
# Access an element or slice using indexing — `s[1:]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
s[1:]

# %% [markdown]
# so to grab a section - from index to end index

# %% [markdown]
# Access an element or slice using indexing — `s[2:5]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
s[2:5]

# %% [markdown]
# ### Lists

# %% [markdown]
# Access an element or slice using indexing — `[1,2,3]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
[1,2,3]

# %% [markdown]
# Access an element or slice using indexing — `['hi',1,[1,2]]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
['hi',1,[1,2]]

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
my_list = ['a','b','c']

# %% [markdown]
# Evaluate `my_list.append('d')` — Jupyter renders the last expression as cell output.

# %%
my_list.append('d')

# %% [markdown]
# Evaluate `my_list` — Jupyter renders the last expression as cell output.

# %%
my_list

# %% [markdown]
# Note indexing is same as for string explained above

# %%
my_list[0]

# %% [markdown]
# Access an element or slice using indexing — `my_list[1]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
my_list[1]

# %% [markdown]
# Access an element or slice using indexing — `my_list[1:]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
my_list[1:]

# %% [markdown]
# Access an element or slice using indexing — `my_list[:1]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
my_list[:1]

# %% [markdown]
# reassign elements in list using index of element

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
my_list[0] = 'NEW'

# %% [markdown]
# Evaluate `my_list` — Jupyter renders the last expression as cell output.

# %%
my_list

# %% [markdown]
# nesting lists

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
nest = [1,2,3,[4,5,['target']]]

# %% [markdown]
# accesses nested list since that is what at index 3

# %% [markdown]
# Access an element or slice using indexing — `nest[3]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
nest[3]

# %% [markdown]
# to access elements within that nested list

# %% [markdown]
# Access an element or slice using indexing — `nest[3][2]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
nest[3][2]

# %% [markdown]
# and further into nested list

# %% [markdown]
# Access an element or slice using indexing — `nest[3][2][0]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
nest[3][2][0]

# %% [markdown]
# ### Dictionaries

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
d = {'key1':'item1','key2':'item2'}

# %% [markdown]
# Evaluate `d` — Jupyter renders the last expression as cell output.

# %%
d

# %% [markdown]
# access values using keys not index

# %% [markdown]
# Access an element or slice using indexing — `d['key1']`. Python uses zero-based indexing, so the first element is at index 0.

# %%
d['key1']

# %% [markdown]
# can even store lists as values

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
d = {'k1':[1,2,3]}

# %% [markdown]
# to access values, use key

# %% [markdown]
# Access an element or slice using indexing — `d['k1']`. Python uses zero-based indexing, so the first element is at index 0.

# %%
d['k1']

# %% [markdown]
# then can access list using indexing with key noted first

# %%
d['k1'][1]

# %% [markdown]
# or can assign list to variable

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
my_list = d['k1']

# %% [markdown]
# Evaluate `my_list` — Jupyter renders the last expression as cell output.

# %%
my_list

# %% [markdown]
# Access an element or slice using indexing — `my_list[1]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
my_list[1]

# %% [markdown]
# nested dictionaries

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
d = {'k1':{'innerkey':[1,2,3]}}

# %% [markdown]
# Access an element or slice using indexing — `d['k1']`. Python uses zero-based indexing, so the first element is at index 0.

# %%
d['k1']

# %% [markdown]
# Access an element or slice using indexing — `d['k1']['innerkey']`. Python uses zero-based indexing, so the first element is at index 0.

# %%
d['k1']['innerkey']

# %% [markdown]
# Access an element or slice using indexing — `d['k1']['innerkey'][1]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
d['k1']['innerkey'][1]

# %% [markdown]
# ### Booleans

# %% [markdown]
# Evaluate `True` — Jupyter renders the last expression as cell output.

# %%
True

# %% [markdown]
# Evaluate `False` — Jupyter renders the last expression as cell output.

# %%
False

# %% [markdown]
# ### Tuples

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
t = (1,2,3)

# %% [markdown]
# Access an element or slice using indexing — `t[0]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
t[0]

# %% [markdown]
# tuples are immutable and do not support item reassignment - cannot reassign like you would a list

# %% [markdown]
# meaning you want to use tuple when you don't want a user to be able to change what's inside

# %%
t[0] = 'NEW'

# %% [markdown]
# ### Sets

# %% [markdown]
# sets = collections of unique elements

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
{1,2,3}

# %% [markdown]
# So will reduce duplicates down to unique elements

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
{1,2,3,1,2,1,2,3,3,3,3,2,2,2,1,1,2}

# %% [markdown]
# can use set as function to grab unique elements for you

# %%
array = [1,1,1,2,2,3,3,3,3,4,4,5,5,5,5,5,6]
set(array)

# %% [markdown]
# to add, use add() instead of append

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
s = {1,2,3}

# %% [markdown]
# Evaluate `s.add(5)` — Jupyter renders the last expression as cell output.

# %%
s.add(5)

# %% [markdown]
# Evaluate `s` — Jupyter renders the last expression as cell output.

# %%
s

# %% [markdown]
# if you try to add a duplicate you won't get an error but your set will remain unchanged

# %%
s.add(1)

# %% [markdown]
# Evaluate `s` — Jupyter renders the last expression as cell output.

# %%
s

# %% [markdown]
# ## Comparison Operators

# %% [markdown]
# Comparison operators return boolean values

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
1 > 2

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
1 < 2

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
1 >= 1

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
1 <= 4

# %% [markdown]
# to check for equality, use ==     using only = will make python think it's variable assignment

# %%
1 == 1

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
'hi' == 'bye'

# %% [markdown]
# to check for inequality

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
1 != 3

# %% [markdown]
# ## Logic Operators

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
(1 > 2) and (2 < 3)

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
(1 > 2) or (2 < 3)

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
(1 == 2) or (2 == 3) or (4 == 4)

# %% [markdown]
# ## if,elif, else Statements

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
if 1 < 2:
    print('Yep!')

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
if 1 < 2:
    print('yep!')

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
if 1 < 2:
    print('first')
else:
    print('last')

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
if 1 > 2:
    print('first')
else:
    print('last')

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
if 1 == 2:
    print('first')
elif 3 == 3:
    print('middle')
else:
    print('Last')

# %% [markdown]
# keep in mind if using multiple elif statements, will stop at first one true, so:

# %%
if 1==2:
    print('first')
elif 4==4:
    print('second')
elif 3==3:
    print('middle')
else:
    print('last')

# %% [markdown]
# ## for Loops

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
seq = [1,2,3,4,5]

# %% [markdown]
# Use for loop to perform action for each element in sequence

# %%
for item in seq:
    print(item)

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
for item in seq:
    print('Yep')

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
for jelly in seq:
    print(jelly+jelly)

# %% [markdown]
# ## while Loops

# %% [markdown]
# Use while loop to perform action until a certain condition is met

# %% [markdown]
# also note that format has been replaced by f"" notation

# %%
i = 1
while i < 5:
    print('i is: {}'.format(i))
    i = i+1

# %% [markdown]
# ## range()

# %% [markdown]
# Evaluate `range(5)` — Jupyter renders the last expression as cell output.

# %%
range(5)

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
for i in range(5):
    print(i)

# %% [markdown]
# range is generator - if you want it as a list, you'll need to assign like so

# %%
list(range(5))

# %% [markdown]
# ## list comprehension

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
x = [1,2,3,4]

# %% [markdown]
# list comprehension is just an easier way to perform some action with an already existing list, to produce another list as output

# %% [markdown]
# Here is using for loop to iterate through list and perform action

# %%
out = []
for item in x:
    out.append(item**2)
print(out)

# %% [markdown]
# to instead use list comprehension - put inside brackets - don't have to instantiate empty list first

# %%
[item**2 for item in x]

# %% [markdown]
# to do it all in one motion:

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
out = [item**2 for item in x]

# %% [markdown]
# Evaluate `out` — Jupyter renders the last expression as cell output.

# %%
out

# %% [markdown]
# ## functions

# %% [markdown]
# using = in parameters sets default value for parameter

# %% [markdown]
# """ notation is how to add in string of multiple lines as a documentation string

# %% [markdown]
# NOTE if you want to know what function docstring is - in jupyter - type function name without (), then shift + tab for description from your docstring

# %% [markdown]
# You will get signature call (what function expects to receive) then your docstring

# %% [markdown]
# This can be used with pre-existing functions as well for a quick reference to the function usage

# %%
def my_func(param1='default'):
    """
    Docstring goes here.
    """
    print(param1)

# %% [markdown]
# if you don't use () - you will not call function - you will just ask python what is this object

# %%
my_func

# %% [markdown]
# to call/execute function

# %% [markdown]
# Evaluate `my_func()` — Jupyter renders the last expression as cell output.

# %%
my_func()

# %% [markdown]
# Evaluate `my_func('new param')` — Jupyter renders the last expression as cell output.

# %%
my_func('new param')

# %% [markdown]
# Evaluate `my_func(param1='new param')` — Jupyter renders the last expression as cell output.

# %%
my_func(param1='new param')

# %% [markdown]
# using return to assign a value

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
def square(x):
    return x**2

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
out = square(2)

# %% [markdown]
# Evaluate `print(out)` — Jupyter renders the last expression as cell output.

# %%
print(out)

# %% [markdown]
# ## lambda expressions

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
def times2(var):
    return var*2

# %% [markdown]
# Evaluate `times2(2)` — Jupyter renders the last expression as cell output.

# %%
times2(2)

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
lambda var: var*2

# %% [markdown]
# ## map and filter

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
seq = [1,2,3,4,5]

# %% [markdown]
# use map to perform a function for each element in a list

# %% [markdown]
# map(function, seq)

# %% [markdown]
# if you don't create new list, will just return object

# %%
map(times2,seq)

# %% [markdown]
# to assign results to a list so they're stored

# %% [markdown]
# Evaluate `list(map(times2,seq))` — Jupyter renders the last expression as cell output.

# %%
list(map(times2,seq))

# %% [markdown]
# generally using map because you don't want to write out a whole function - you want to perform a simple expression

# %% [markdown]
# so instead you use lambda

# %% [markdown]
# use lambda """what you want to pass in> : <what you want to return out""" , seq

# %%
list(map(lambda var: var*2,seq))

# %% [markdown]
# use filter in a similar way

# %% [markdown]
# here, lambda expression takes condition and returns True or False for element in iterable object (so a list) and returns when True

# %%
filter(lambda item: item%2 == 0,seq)

# %% [markdown]
# cast to list to see actual output

# %% [markdown]
# For example to see even numbers in list

# %% [markdown]
# Evaluate `list(filter(lambda item: item%2 == 0,seq))` — Jupyter renders the last expression as cell output.

# %%
list(filter(lambda item: item%2 == 0,seq))

# %% [markdown]
# ## methods

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
st = 'hello my name is Sam'

# %% [markdown]
# so if you type "st" then hit tab in jupyter, you will get a list of all methods you can call on string object

# %%
st.lower()

# %% [markdown]
# Evaluate `st.upper()` — Jupyter renders the last expression as cell output.

# %%
st.upper()

# %% [markdown]
# splits on whitespace by default

# %% [markdown]
# Evaluate `st.split()` — Jupyter renders the last expression as cell output.

# %%
st.split()

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
tweet = 'Go Sports! #Sports'

# %% [markdown]
# Evaluate `tweet.split('#')` — Jupyter renders the last expression as cell output.

# %%
tweet.split('#')

# %% [markdown]
# Access an element or slice using indexing — `tweet.split('#')[1]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
tweet.split('#')[1]

# %% [markdown]
# Evaluate `d` — Jupyter renders the last expression as cell output.

# %%
d

# %% [markdown]
# Evaluate `d.keys()` — Jupyter renders the last expression as cell output.

# %%
d.keys()

# %% [markdown]
# Evaluate `d.items()` — Jupyter renders the last expression as cell output.

# %%
d.items()

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
lst = [1,2,3]

# %% [markdown]
# pop will "pop" the last item out of the list and return it - so remove from list and return

# %%
lst.pop()

# %% [markdown]
# Evaluate `lst` — Jupyter renders the last expression as cell output.

# %%
lst

# %% [markdown]
# can also use pop with index

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
first = lst.pop(0)

# %% [markdown]
# Evaluate `lst` — Jupyter renders the last expression as cell output.

# %%
lst

# %% [markdown]
# Evaluate `first` — Jupyter renders the last expression as cell output.

# %%
first

# %% [markdown]
# Access an element or slice using indexing — `'x' in [1,2,3]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
'x' in [1,2,3]

# %% [markdown]
# Access an element or slice using indexing — `'x' in ['x','y','z']`. Python uses zero-based indexing, so the first element is at index 0.

# %%
'x' in ['x','y','z']

# %% [markdown]
# Tuple unpacking

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
x = [(1,2),(3,4),(5,6)]

# %% [markdown]
# Access an element or slice using indexing — `x[0]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
x[0]

# %% [markdown]
# normal iterating through items

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
for item in x:
    print(item)

# %% [markdown]
# to instead unpack within for loop

# %% [markdown]
# The code below implements the next step in this NumPy workflow. See the inline comments for details on each operation.

# %%
for (a,b) in x:
    print(a)

# %% [markdown]
# # Great Job!
