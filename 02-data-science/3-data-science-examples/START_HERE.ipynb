# %% [markdown]
# **Create a DataFrame:** Pandas DataFrames are 2D labeled data structures — they're the backbone of data science in Python. Each column can hold a different data type (numbers, strings, dates). DataFrames support powerful operations: filtering, grouping, merging, reshaping, and aggregation.
#
# **Line Plot:** Connects data points with lines — ideal for showing trends over a continuous variable (often time). In ML, line plots are commonly used for:
# - Training/validation loss curves (to detect overfitting)
# - Learning rate schedules
# - Time series data

# %%
# Install essential packages
# Uncomment and run if needed:
# !pip install numpy pandas matplotlib seaborn scikit-learn

# Verify installation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("✅ Data Science Stack Installed!")
print(f"\nnumpy: {np.__version__}")
print(f"pandas: {pd.__version__}")
print(f"matplotlib: {plt.matplotlib.__version__}")

# Quick test
data = pd.DataFrame({
    'x': np.arange(10),
    'y': np.random.randn(10)
})

print("\nSample Data:")
print(data.head())

# Simple visualization
plt.figure(figsize=(8, 4))
plt.plot(data['x'], data['y'], marker='o')
plt.title('You\'re Ready to Start!')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True, alpha=0.3)
plt.show()

print("\n🎉 Everything works! You can start learning now.")

# %% [markdown]
# ## 📖 Study Schedule Examples
#
# ### Full-Time Learner (40 hours/week)
# **Path to Data Scientist: 12-16 weeks**
#
# - **Morning (4 hours):** Learn new concepts from course
# - **Afternoon (3 hours):** Practice exercises and projects
# - **Evening (1 hour):** Review, document, and plan next day
#
# ### Part-Time Learner (15 hours/week)
# **Path to Data Scientist: 30-40 weeks**
#
# - **Weekday evenings (1.5 hours × 5):** Course material
# - **Weekend mornings (3 hours × 2):** Projects and practice
# - **Sunday evening (1.5 hours):** Review week, plan ahead
#
# ### Casual Learner (5-7 hours/week)
# **Path to Data Scientist: 60-80 weeks**
#
# - **Daily (30-45 min):** Consistent learning
# - **Weekend (2-3 hours):** Hands-on practice
#
# ---
#
# ## 💡 Success Tips
#
# ### 1. Start with Microsoft Course
# ```
# Don't skip ahead!
# The Microsoft course builds a solid foundation.
# Everything else builds on this.
# ```
#
# ### 2. Code Every Day
# ```python
# # 30 minutes daily > 3 hours on Sunday
# # Consistency builds muscle memory
# # Track your streak!
# ```
#
# ### 3. Build Projects
# ```
# Theory: 30%
# Practice: 70%
#
# After each module, build something!
# ```
#
# ### 4. Join Communities
# - **Kaggle:** Competitions and discussions
# - **r/datascience:** Reddit community
# - **Discord/Slack:** Real-time help
#
# ### 5. Document Your Journey
# ```markdown
# Create a learning journal:
# - What you learned
# - Challenges faced
# - Solutions found
# - Projects built
#
# → Becomes your portfolio!
# ```
#
# ### 6. Review Regularly
# ```
# Spaced repetition:
# - Day 1: Learn
# - Day 3: Review
# - Week 1: Practice
# - Month 1: Teach someone
# ```
#
# ---
#
# ## 🎓 Skill Progression
#
# ### Month 1-2: Foundation
# - ✅ Python basics
# - ✅ NumPy arrays
# - ✅ pandas DataFrames
# - ✅ Data visualization
# - ✅ Basic statistics
#
# ### Month 3-5: Machine Learning
# - ✅ Supervised learning
# - ✅ Unsupervised learning
# - ✅ Model evaluation
# - ✅ Feature engineering
# - ✅ First Kaggle competition
#
# ### Month 6-9: Advanced ML
# - ✅ Deep learning
# - ✅ Neural networks
# - ✅ Computer vision
# - ✅ NLP basics
# - ✅ Portfolio projects
#
# ### Month 10-12: Production
# - ✅ Cloud deployment (AWS)
# - ✅ Big data (Spark)
# - ✅ ML pipelines
# - ✅ Job applications
# - ✅ Interview prep
#
# ---
#
# ## 📊 Track Your Progress
#
# ### Foundation Track ☐
# - [ ] Completed Microsoft Course (Modules 1-2)
# - [ ] Built first data analysis project
# - [ ] Mastered pandas basics
# - [ ] Created 5+ visualizations
#
# ### ML Track ☐
# - [ ] Completed all scikit-learn references
# - [ ] Submitted first Kaggle competition
# - [ ] Built 3 ML projects
# - [ ] Achieved 70%+ accuracy on test set
#
# ### DL Track ☐
# - [ ] Trained first neural network
# - [ ] Built CNN for image classification
# - [ ] Implemented RNN for sequences
# - [ ] Completed 2 DL projects
#
# ### Production Track ☐
# - [ ] Deployed model to AWS
# - [ ] Processed data with Spark
# - [ ] Built end-to-end pipeline
# - [ ] Created portfolio website
#
# ---
#
# ## 🔗 Essential Resources
#
# ### Documentation
# - [NumPy](https://numpy.org/doc/)
# - [pandas](https://pandas.pydata.org/docs/)
# - [scikit-learn](https://scikit-learn.org/stable/)
# - [TensorFlow](https://www.tensorflow.org/api_docs)
#
# ### Communities
# - [Kaggle](https://www.kaggle.com/) - Competitions & datasets
# - [Reddit r/datascience](https://www.reddit.com/r/datascience/)
# - [Stack Overflow](https://stackoverflow.com/questions/tagged/data-science)
#
# ### Practice
# - [LeetCode](https://leetcode.com/) - Coding challenges
# - [HackerRank](https://www.hackerrank.com/domains/ai) - Data science track
# - [DataCamp](https://www.datacamp.com/) - Interactive courses
#
# ---
#
# ## 🎯 Your Next Steps
#
# ### Right Now (Next 10 minutes):
# 1. ✅ Run the setup cell above
# 2. ✅ Read the [README.md](README.md)
# 3. ✅ Open [01-microsoft-course/1-Introduction](01-microsoft-course/1-Introduction/)
#
# ### This Week:
# 1. Complete Introduction module
# 2. Set up learning journal
# 3. Join Kaggle community
# 4. Start tracking progress
#
# ### This Month:
# 1. Finish Working with Data module
# 2. Build first analysis project
# 3. Share progress on social media
# 4. Review and adjust schedule
#
# ---
#
# ## 💪 Motivation
#
# ### Remember:
# - **This is a marathon, not a sprint**
# - **Every expert was once a beginner**
# - **Consistency beats intensity**
# - **Progress over perfection**
#
# ### You Have Everything You Need:
# - ✅ 122 curated notebooks (from 919)
# - ✅ Official Microsoft curriculum
# - ✅ Real competition examples
# - ✅ Complete learning paths
# - ✅ 30-40 week roadmap to job-ready
#
# ---
#
# ## 🚀 Ready to Begin?
#
# **Your first step:** [01-microsoft-course/1-Introduction](01-microsoft-course/1-Introduction/)
#
# **Good luck on your data science journey! 📊🎓**
