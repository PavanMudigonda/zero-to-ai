# %% [markdown]
# # Phase 28: Practical Data Science — Start Here
#
# ---
#
# Hands-on, medium-depth notebooks covering the full data science stack — from pandas fundamentals to deep learning, from SQL engineering to causal inference. Each notebook is self-contained with real runnable code, honest gotchas, and exercises.
#
# ---
#
# ## About This Phase
#
# These notebooks follow the philosophy of the best data science writing on the internet:
# - **Practical** — real code, not toy examples
# - **Medium depth** — bridging theory and production
# - **The "why"** behind every technique
# - **Honest gotchas** — what fails and why
#
# **Difficulty key:** ★☆☆ beginner · ★★☆ intermediate · ★★★ advanced
#
# ## Nine Tracks
#
# | Track | Directory | What You'll Learn |
# |-------|-----------|-------------------|
# | **Python & Data Science** | `python-data-science/` | pandas mastery, EDA, visualization, feature engineering |
# | **Machine Learning** | `machine-learning/` | sklearn pipelines, ensembles, imbalanced data, SHAP |
# | **Deep Learning & NLP** | `deep-learning-nlp/` | Transformer math, BERT fine-tuning, LoRA |
# | **Statistics & MLOps** | `statistics-mlops/` | A/B testing, Bayesian thinking, FastAPI, feature stores |
# | **Time Series & Forecasting** | `time-series-forecasting/` | ARIMA, Prophet, LSTM, model comparison |
# | **Computer Vision** | `computer-vision/` | CNNs, transfer learning, object detection, segmentation |
# | **SQL & Data Engineering** | `sql-data-engineering/` | Advanced SQL, Spark, dbt, streaming |
# | **Recommender Systems & Causal Inference** | `recommender-causal/` | Collaborative filtering, neural CF, A/B platform |
# | **Interview Prep** | (root) | 30 questions that appear in 80% of DS interviews |
#
# ---
#
# ## Python & Data Science
#
# | Notebook | Topic | Difficulty | Time |
# |----------|-------|-----------|------|
# | `01_pandas_fundamentals.ipynb` | groupby, merge, pivot, method chaining | ★☆☆ | 45 min |
# | `02_exploratory_data_analysis.ipynb` | Profiling, distributions, correlations | ★☆☆ | 45 min |
# | `03_data_visualization.ipynb` | matplotlib, seaborn, plotly | ★☆☆ | 40 min |
# | `04_data_cleaning_pipelines.ipynb` | Missing values, ColumnTransformer | ★★☆ | 50 min |
# | `05_feature_engineering.ipynb` | Encoding, scaling, polynomial features | ★★☆ | 60 min |
#
# ## Machine Learning
#
# | Notebook | Topic | Difficulty | Time |
# |----------|-------|-----------|------|
# | `01_sklearn_pipelines.ipynb` | Pipeline, ColumnTransformer | ★★☆ | 60 min |
# | `02_model_selection_validation.ipynb` | Cross-val, GridSearchCV, bias-variance | ★★☆ | 60 min |
# | `03_ensemble_methods.ipynb` | RandomForest, GBM, XGBoost, stacking | ★★☆ | 60 min |
# | `04_imbalanced_datasets.ipynb` | SMOTE, threshold tuning | ★★☆ | 50 min |
# | `05_model_interpretability.ipynb` | SHAP, permutation importance, PDP | ★★★ | 60 min |
# | `06_end_to_end_project.ipynb` | Full churn prediction project | ★★★ | 90 min |
#
# ## Deep Learning & NLP
#
# | Notebook | Topic | Difficulty | Time |
# |----------|-------|-----------|------|
# | `01_transformers_from_scratch.ipynb` | Self-attention math, positional encoding | ★★★ | 90 min |
# | `02_bert_text_classification.ipynb` | Fine-tune DistilBERT with HF Trainer | ★★★ | 75 min |
# | `03_llm_applications_patterns.ipynb` | Structured output, function calling, RAG | ★★☆ | 60 min |
# | `04_text_preprocessing.ipynb` | TF-IDF, tokenization, spaCy | ★★☆ | 45 min |
# | `05_llm_finetuning_lora.ipynb` | LoRA/QLoRA, PEFT, memory math | ★★★ | 90 min |
#
# ## Statistics & MLOps
#
# | Notebook | Topic | Difficulty | Time |
# |----------|-------|-----------|------|
# | `01_hypothesis_testing.ipynb` | t-test, A/B testing, multiple testing | ★★☆ | 60 min |
# | `02_bayesian_thinking.ipynb` | Bayes' theorem, MCMC, credible intervals | ★★★ | 75 min |
# | `03_model_deployment_fastapi.ipynb` | FastAPI, Docker, Gunicorn | ★★☆ | 60 min |
# | `04_ml_monitoring_drift.ipynb` | KS drift, PSI, alerting | ★★☆ | 60 min |
# | `05_feature_stores.ipynb` | Point-in-time joins, offline/online store | ★★★ | 75 min |
#
# ## Time Series & Forecasting
#
# | Notebook | Topic | Difficulty | Time |
# |----------|-------|-----------|------|
# | `01_time_series_fundamentals.ipynb` | Stationarity, decomposition, ACF/PACF | ★★☆ | 60 min |
# | `02_arima_sarima.ipynb` | Box-Jenkins workflow, residual diagnostics | ★★★ | 75 min |
# | `03_prophet_forecasting.ipynb` | Prophet with holidays, regressors | ★★☆ | 60 min |
# | `04_lstm_time_series.ipynb` | LSTM forecaster, walk-forward eval | ★★★ | 75 min |
# | `05_anomaly_detection.ipynb` | Z-score, Isolation Forest, LOF | ★★☆ | 60 min |
# | `06_forecasting_competition.ipynb` | ARIMA vs Prophet vs LSTM leaderboard | ★★★ | 90 min |
#
# ## Computer Vision
#
# | Notebook | Topic | Difficulty | Time |
# |----------|-------|-----------|------|
# | `01_image_processing_basics.ipynb` | Image arrays, color spaces, convolution | ★☆☆ | 45 min |
# | `02_cnn_from_scratch.ipynb` | SimpleCNN, training loop, filters | ★★★ | 75 min |
# | `03_transfer_learning.ipynb` | Feature extraction vs fine-tuning | ★★★ | 75 min |
# | `04_object_detection.ipynb` | IoU, NMS, Faster R-CNN, mAP | ★★☆ | 60 min |
# | `05_image_segmentation.ipynb` | U-Net, skip connections, mIoU | ★★★ | 75 min |
#
# ## SQL & Data Engineering
#
# | Notebook | Topic | Difficulty | Time |
# |----------|-------|-----------|------|
# | `01_advanced_sql.ipynb` | Window functions, CTEs, recursive queries | ★★☆ | 60 min |
# | `02_query_optimization.ipynb` | EXPLAIN, indexes, partitioning | ★★☆ | 60 min |
# | `03_data_pipelines_airflow.ipynb` | DAGs, operators, sensors | ★★★ | 75 min |
# | `04_spark_pyspark_basics.ipynb` | DataFrames, actions, broadcast joins | ★★★ | 75 min |
# | `05_dbt_data_modeling.ipynb` | Models, tests, docs, incremental | ★★☆ | 60 min |
# | `06_streaming_basics.ipynb` | Kafka, windowed aggregations, exactly-once | ★★★ | 75 min |
#
# ## Recommender Systems & Causal Inference
#
# | Notebook | Topic | Difficulty | Time |
# |----------|-------|-----------|------|
# | `01_collaborative_filtering.ipynb` | User-item matrix, SVD, ALS | ★★☆ | 60 min |
# | `02_content_based_filtering.ipynb` | TF-IDF similarity, hybrid systems | ★★☆ | 60 min |
# | `03_neural_collaborative_filtering.ipynb` | Embeddings, GMF, MLP, NeuMF | ★★★ | 75 min |
# | `04_causal_inference_basics.ipynb` | Potential outcomes, PSM, DML | ★★★ | 75 min |
# | `05_difference_in_differences.ipynb` | DiD, parallel trends, event study | ★★★ | 90 min |
# | `06_ab_testing_platform.ipynb` | Assignment engine, mSPRT, CUPED | ★★★ | 75 min |
#
# ## Interview Prep
#
# | Notebook | Topic | Difficulty | Time |
# |----------|-------|-----------|------|
# | `00_INTERVIEW_PREP.ipynb` | 30 questions: stats, ML, SQL, DL, system design | ★★★ | 120 min |
#
# ---
#
# ## Prerequisites
# - Python basics (Phase 01)
# - NumPy/pandas fundamentals (Phase 02)
# - ML concepts helpful for ML, DL, and CV tracks
#
# ## Install dependencies
# ```bash
# pip install -r requirements.txt
#
# # Minimal install (no heavy optional deps):
# pip install numpy pandas scipy scikit-learn matplotlib seaborn xgboost \
#             imbalanced-learn shap torch torchvision transformers datasets \
#             statsmodels prophet sqlalchemy duckdb faiss-cpu \
#             fastapi uvicorn pydantic jupyter tqdm networkx pillow
# ```
#
# ## Recommended Learning Paths
#
# ```
# New to data science (20h):
#   python-data-science/ (all 5) → machine-learning/01-04 → statistics-mlops/01
#
# ML engineer path (30h):
#   machine-learning/ (all) → statistics-mlops/ (all) → 00_INTERVIEW_PREP
#
# Deep learning / NLP focus (25h):
#   deep-learning-nlp/ (all) → computer-vision/ (all) → recommender-causal/03
#
# Data engineering focus (20h):
#   sql-data-engineering/ (all) → statistics-mlops/03-05
#
# Research / causal inference (25h):
#   statistics-mlops/01-02 → recommender-causal/04-06 → 00_INTERVIEW_PREP
#
# Interview preparation (12h):
#   00_INTERVIEW_PREP → machine-learning/02,05 → statistics-mlops/01 → sql-data-engineering/01
# ```
