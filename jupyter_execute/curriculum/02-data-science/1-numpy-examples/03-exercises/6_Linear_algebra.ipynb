# %% [markdown]
# # Linear algebra

# %% [markdown]
# Import the libraries needed for this section:
# - **numpy**

# %%
import numpy as np

# %% [markdown]
# Evaluate `np.__version__` — Jupyter renders the last expression as cell output.

# %%
np.__version__

# %% [markdown]
# ## Matrix and vector products

# %% [markdown]
# Q1. Predict the results of the following code.

# %% [markdown]
# **Dot Product (Inner Product):** The dot product of two vectors measures how much they point in the same direction. It's computed by multiplying corresponding elements and summing the results:
#
# $$\mathbf{a} \cdot \mathbf{b} = \sum_{i} a_i \times b_i$$
#
# - If the result is **positive**, the vectors point in roughly the same direction
# - If **zero**, the vectors are perpendicular (orthogonal)
# - If **negative**, they point in opposite directions
#
# In ML, dot products are everywhere: every neuron in a neural network computes a dot product of inputs with weights, and cosine similarity is built on it.
#
# **Matrix Multiplication:** The core operation in nearly all ML. When you multiply matrices $A$ (m×n) and $B$ (n×p), each element of the result is a **dot product** — a row of $A$ dotted with a column of $B$:
#
# $$C_{ij} = \sum_{k=1}^{n} A_{ik} \cdot B_{kj}$$
#
# **Why it matters:**
# - Every neural network layer computes $\text{output} = W \cdot \text{input} + b$
# - Transformers use matrix multiplication extensively for attention scores
# - The `@` operator in Python/NumPy is shorthand for `np.matmul()`

# %%
x = [1,2]
y = [[4, 1], [2, 2]]
#print np.dot(x, y)
#print np.dot(y, x)
#print np.matmul(x, y)
#print np.inner(x, y)
#print np.inner(y, x)

# %% [markdown]
# Q2. Predict the results of the following code.

# %% [markdown]
# **Dot Product (Inner Product):** The dot product of two vectors measures how much they point in the same direction. It's computed by multiplying corresponding elements and summing the results:
#
# $$\mathbf{a} \cdot \mathbf{b} = \sum_{i} a_i \times b_i$$
#
# - If the result is **positive**, the vectors point in roughly the same direction
# - If **zero**, the vectors are perpendicular (orthogonal)
# - If **negative**, they point in opposite directions
#
# In ML, dot products are everywhere: every neuron in a neural network computes a dot product of inputs with weights, and cosine similarity is built on it.
#
# **Matrix Multiplication:** The core operation in nearly all ML. When you multiply matrices $A$ (m×n) and $B$ (n×p), each element of the result is a **dot product** — a row of $A$ dotted with a column of $B$:
#
# $$C_{ij} = \sum_{k=1}^{n} A_{ik} \cdot B_{kj}$$
#
# **Why it matters:**
# - Every neural network layer computes $\text{output} = W \cdot \text{input} + b$
# - Transformers use matrix multiplication extensively for attention scores
# - The `@` operator in Python/NumPy is shorthand for `np.matmul()`

# %%
x = [[1, 0], [0, 1]]
y = [[4, 1], [2, 2], [1, 1]]
#print np.dot(y, x)
#print np.matmul(y, x)

# %% [markdown]
# Q3. Predict the results of the following code.

# %% [markdown]
# **Dot Product (Inner Product):** The dot product of two vectors measures how much they point in the same direction. It's computed by multiplying corresponding elements and summing the results:
#
# $$\mathbf{a} \cdot \mathbf{b} = \sum_{i} a_i \times b_i$$
#
# - If the result is **positive**, the vectors point in roughly the same direction
# - If **zero**, the vectors are perpendicular (orthogonal)
# - If **negative**, they point in opposite directions
#
# In ML, dot products are everywhere: every neuron in a neural network computes a dot product of inputs with weights, and cosine similarity is built on it.

# %%
x = np.array([[1, 4], [5, 6]])
y = np.array([[4, 1], [2, 2]])
#print np.vdot(x, y)
#print np.vdot(y, x)
#print np.dot(x.flatten(), y.flatten())
#print np.inner(x.flatten(), y.flatten())
#print (x*y).sum()

# %% [markdown]
# Q4. Predict the results of the following code.

# %% [markdown]
# print np.inner(x, y)
# print np.inner(y, x)
# print np.outer(x, y)
#
# The code below implements this step in the linear algebra workflow.

# %%
x = np.array(['a', 'b'], dtype=object)
y = np.array([1, 2])
#print np.inner(x, y)
#print np.inner(y, x)
#print np.outer(x, y)
#print np.outer(y, x)

# %% [markdown]
# ## Decompositions

# %% [markdown]
# Q5. Get the lower-trianglular `L` in the Cholesky decomposition of x and verify it.

# %%
x = np.array([[4, 12, -16], [12, 37, -43], [-16, -43, 98]], dtype=np.int32)

# %% [markdown]
# Q6. Compute the qr factorization of x and verify it.

# %%
x = np.array([[12, -51, 4], [6, 167, -68], [-4, 24, -41]], dtype=np.float32)

# %% [markdown]
# Q7. Factor x by Singular Value Decomposition and verify it.

# %%
x = np.array([[1, 0, 0, 0, 2], [0, 0, 3, 0, 0], [0, 0, 0, 0, 0], [0, 2, 0, 0, 0]], dtype=np.float32)

# %% [markdown]
# ## Matrix eigenvalues

# %% [markdown]
# Q8. Compute the eigenvalues and right eigenvectors of x. (Name them eigenvals and eigenvecs, respectively)

# %%
x = np.diag((1, 2, 3))

# %% [markdown]
# Q9. Predict the results of the following code.

# %% [markdown]
# ### print np.array_equal(np.dot(x, eigenvecs), eigenvals * eigenvecs)
#
# The code below implements this step in the NumPy array operations workflow.

# %%
#print np.array_equal(np.dot(x, eigenvecs), eigenvals * eigenvecs)

# %% [markdown]
# ## Norms and other numbers

# %% [markdown]
# Q10. Calculate the Frobenius norm and the condition number of x.

# %%
x = np.arange(1, 10).reshape((3, 3))

# %% [markdown]
# Q11. Calculate the determinant of x.

# %% [markdown]
# The code below implements the next step in this linear algebra workflow. See the inline comments for details on each operation.

# %%
x = np.arange(1, 5).reshape((2, 2))

# %% [markdown]
# Q12. Calculate the rank of x.

# %% [markdown]
# **Identity Matrix ($I$):** The "number 1" of matrix math — multiplying any matrix by $I$ returns the same matrix: $AI = IA = A$. It's a square matrix with 1s on the diagonal and 0s elsewhere.

# %%
x = np.eye(4)

# %% [markdown]
# Q13. Compute the sign and natural logarithm of the determinant of x.

# %%
x = np.arange(1, 5).reshape((2, 2))

# %% [markdown]
# Q14. Return the sum along the diagonal of x.

# %% [markdown]
# **Identity Matrix ($I$):** The "number 1" of matrix math — multiplying any matrix by $I$ returns the same matrix: $AI = IA = A$. It's a square matrix with 1s on the diagonal and 0s elsewhere.

# %%
x = np.eye(4)

# %% [markdown]
# ## Solving equations and inverting matrices

# %% [markdown]
# Q15. Compute the inverse of x.

# %% [markdown]
# The code below implements the next step in this linear algebra workflow. See the inline comments for details on each operation.

# %%
x = np.array([[1., 2.], [3., 4.]])
