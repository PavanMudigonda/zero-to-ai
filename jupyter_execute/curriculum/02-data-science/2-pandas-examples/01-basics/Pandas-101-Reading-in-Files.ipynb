# %% [markdown]
# # Reading In Files

# %% [markdown]
# Import the libraries needed for this section:
# - **pandas**

# %%
import pandas as pd

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
df = pd.read_csv(r"C:\Users\alexf\OneDrive\Documents\Pandas Tutorial\countries of the world.csv")
df

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
#df = pd.read_csv(r"C:\Users\alexf\OneDrive\Documents\Pandas Tutorial\countries of the world.txt", sep = '\t')
#df

df = pd.read_table(r"C:\Users\alexf\OneDrive\Documents\Pandas Tutorial\countries of the world.csv", sep = ',')
df

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df = pd.read_json(r"C:\Users\alexf\OneDrive\Documents\Pandas Tutorial\json_sample.json")
df

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df2 = pd.read_excel(r"C:\Users\alexf\OneDrive\Documents\Pandas Tutorial\world_population_excel_workbook.xlsx", sheet_name = 'Sheet1')
df2

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
pd.set_option('display.max.rows', 235)
pd.set_option('display.max.columns', 40)

# %% [markdown]
# **DataFrame.info():** Shows column names, data types, non-null counts, and memory usage. Quickly reveals: which columns have missing values, which are the wrong type (e.g., numbers stored as strings), and how much memory the data uses.

# %%
df2.info()

# %% [markdown]
# Evaluate `df2.shape` — Jupyter renders the last expression as cell output.

# %%
df2.shape

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
df2.head(10)

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
df2.tail(10)

# %% [markdown]
# Access an element or slice using indexing — `df2['Rank']`. Python uses zero-based indexing, so the first element is at index 0.

# %%
df2['Rank']

# %% [markdown]
# Access an element or slice using indexing — `df2.loc['Uzbekistan']`. Python uses zero-based indexing, so the first element is at index 0.

# %%
df2.loc['Uzbekistan']

# %% [markdown]
# Access an element or slice using indexing — `df2.iloc[224]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
df2.iloc[224]
