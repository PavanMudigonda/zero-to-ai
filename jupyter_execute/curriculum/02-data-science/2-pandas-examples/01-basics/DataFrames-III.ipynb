# %% [markdown]
# ## set_index() & reset_index() Methods

# %% [markdown]
# Import the libraries needed for this section:
# - **pandas**

# %%
import pandas as pd

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv('jamesbond.csv')
bond.head(3)

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
bond.set_index("Film", inplace = True)
bond.head(3)

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
bond.reset_index(drop = False, inplace = True)
bond.head(3)

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
bond.reset_index(inplace = True)
bond.set_index("Year", inplace = True)
bond.head(3)

# %% [markdown]
# ## Retrieve Rows by Index Label with .loc[]

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)

# %% [markdown]
# **DataFrame Indexing:** Access specific rows/columns:
# - `.iloc[row, col]`: integer-based (position)
# - `.loc[label, col]`: label-based (index values)
# - `.drop()`: remove rows/columns by label

# %%
bond.loc["Goldfinger"]
bond.loc["GoldenEye"]
bond.loc["Casino Royale"]
bond.loc[: "On Her Majesty's Secret Service"]

# %% [markdown]
# **DataFrame Indexing:** Access specific rows/columns:
# - `.iloc[row, col]`: integer-based (position)
# - `.loc[label, col]`: label-based (index values)
# - `.drop()`: remove rows/columns by label

# %%
bond.loc["Diamonds Are Forever" : "Moonraker"]
bond.loc["GoldenEye" :]

# %% [markdown]
# Access an element or slice using indexing — `bond.loc[["Moonraker", "Octopussy"]]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond.loc[["Moonraker", "Octopussy"]]

# %% [markdown]
# **DataFrame Indexing:** Access specific rows/columns:
# - `.iloc[row, col]`: integer-based (position)
# - `.loc[label, col]`: label-based (index values)
# - `.drop()`: remove rows/columns by label

# %%
bond.loc[["For Your Eyes Only", "Live and Let Die"]]

# %% [markdown]
# ## Retrieve Row(s) by Index Position with iloc

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head(3)

# %% [markdown]
# **DataFrame Indexing:** Access specific rows/columns:
# - `.iloc[row, col]`: integer-based (position)
# - `.loc[label, col]`: label-based (index values)
# - `.drop()`: remove rows/columns by label

# %%
bond.loc[15]
bond.iloc[15]

bond.iloc[[15,20]]
bond.iloc[:4]
bond.iloc[4:8]
bond.iloc[20:]

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace = True)
bond.head(3)

# %% [markdown]
# Access an element or slice using indexing — `bond.iloc[0]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond.iloc[0]

# %% [markdown]
# Access an element or slice using indexing — `bond.iloc[[5, 10, 15, 20]]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond.iloc[[5, 10, 15, 20]]

# %% [markdown]
# ## The Catch-All .ix[] Method

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace = True)
bond.head(3)

# %% [markdown]
# Access an element or slice using indexing — `bond.loc["GoldenEye"]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond.loc["GoldenEye"]

# %% [markdown]
# ### ix method is depreciated
#
# The code below implements this step in the Pandas data manipulation workflow.

# %%
#ix method is depreciated

# %% [markdown]
# ## Second Argument to .loc[], .iloc[], and .ix[] Methods

# %%
pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)

# %% [markdown]
# **DataFrame Indexing:** Access specific rows/columns:
# - `.iloc[row, col]`: integer-based (position)
# - `.loc[label, col]`: label-based (index values)
# - `.drop()`: remove rows/columns by label

# %%
bond.loc["Moonraker", "Director" : "Budget"]

# %% [markdown]
# Access an element or slice using indexing — `bond.iloc[14, [5,3,2]]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond.iloc[14, [5,3,2]]

# %% [markdown]
# ## Set New Values for Specific Cell or Row

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)

# %% [markdown]
# Access an element or slice using indexing — `bond.loc['Dr. No']`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond.loc['Dr. No']

# %% [markdown]
# **DataFrame Indexing:** Access specific rows/columns:
# - `.iloc[row, col]`: integer-based (position)
# - `.loc[label, col]`: label-based (index values)
# - `.drop()`: remove rows/columns by label

# %%
bond.loc['Dr. No', 'Actor'] = 'Sir Sean Connery'

# %% [markdown]
# **DataFrame Indexing:** Access specific rows/columns:
# - `.iloc[row, col]`: integer-based (position)
# - `.loc[label, col]`: label-based (index values)
# - `.drop()`: remove rows/columns by label

# %%
bond.loc['Dr. No', ['Box Office', 'Budget', 'Bond Actor Salary']] = [448800000, 7000000, 600000]
bond.loc['Dr. No']

# %% [markdown]
# ## Set Multiple Values in DataFrame

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
bond.sort_index(inplace = True)
bond.head(3)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
mask = bond['Actor'] == 'Sean Connery'

# %% [markdown]
# Access an element or slice using indexing — `bond[mask]['Actor']`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond[mask]['Actor']

# %% [markdown]
# **DataFrame Indexing:** Access specific rows/columns:
# - `.iloc[row, col]`: integer-based (position)
# - `.loc[label, col]`: label-based (index values)
# - `.drop()`: remove rows/columns by label

# %%
bond.loc[mask, 'Actor'] = 'Sir Sean Connery'

# %% [markdown]
# Evaluate `bond` — Jupyter renders the last expression as cell output.

# %%
bond

# %% [markdown]
# ## Rename Index Labels or Columns in a DataFrame

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
bond.sort_index(inplace = True)
bond.head(3)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
bond.rename(columns = {'Year' : 'Release Date', 'Box Office' : 'Revenue'}, inplace = True)

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
bond.head(1)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
bond.rename(index = {'Dr. No' : 'Doctor No', 
                     'GoldenEye' : 'Golden Eye', 
                     'The World is Not Enough' : 'Best Bond Movie Ever'}, inplace = True)

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
bond.head(1)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
bond.columns = ('Year of Release', 'Actor', 'Director', 'Gross', 'Cost', 'Salary')

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
bond.head(3)

# %% [markdown]
# ## Delete Rows or Columns from a DataFrame

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
bond.sort_index(inplace = True)
bond.head(3)

# %% [markdown]
# ### bond.drop(['Casino Royale'], inplace = True)
#
# The code below implements this step in the Pandas data manipulation workflow.

# %%
# bond.drop(['Casino Royale'], inplace = True)

# %% [markdown]
# **DataFrame Indexing:** Access specific rows/columns:
# - `.iloc[row, col]`: integer-based (position)
# - `.loc[label, col]`: label-based (index values)
# - `.drop()`: remove rows/columns by label

# %%
bond.drop(labels = ['Box Office', 'Actor', 'Bond Actor Salary'], axis = "columns", inplace = True)

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
bond.head(3)

# %% [markdown]
# ## Create Random Sample

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
pd.read_csv('jamesbond.csv', index_col='film')
bond.sort_index(inplace = True)
bond.head(3)

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
bond.sort_index(inplace = True)
bond.head(3)

# %% [markdown]
# Evaluate `bond.sample(n=3, axis = 'columns')` — Jupyter renders the last expression as cell output.

# %%
bond.sample(n=3, axis = 'columns')

# %% [markdown]
# ## The .nsmallest ( ) and n.largest ( ) Methods

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
bond.sort_index(inplace = True)
bond.head(3)

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.
#
# **Sort DataFrame:** Orders rows by one or more columns. Useful for finding top/bottom values, ranking features, and preparing data for sequential analysis.

# %%
bond.sort_values('Box Office', ascending = False)
bond.head(3)

# %% [markdown]
# Evaluate `bond.nlargest(3, columns='Box Office')` — Jupyter renders the last expression as cell output.

# %%
bond.nlargest(3, columns='Box Office')

# %% [markdown]
# Evaluate `bond.nsmallest(3, columns='Box Office')` — Jupyter renders the last expression as cell output.

# %%
bond.nsmallest(3, columns='Box Office')

# %% [markdown]
# Evaluate `bond.nlargest(3, columns='Budget')` — Jupyter renders the last expression as cell output.

# %%
bond.nlargest(3, columns='Budget')

# %% [markdown]
# Evaluate `bond.nsmallest(3, columns='Bond Actor Salary')` — Jupyter renders the last expression as cell output.

# %%
bond.nsmallest(3, columns='Bond Actor Salary')

# %% [markdown]
# Access an element or slice using indexing — `bond['Box Office'].nlargest(8)`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond['Box Office'].nlargest(8)

# %% [markdown]
# Access an element or slice using indexing — `bond['Year'].nsmallest(2)`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond['Year'].nsmallest(2)

# %% [markdown]
# ## Filtering with the where Method

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
bond.sort_index(inplace = True)
bond.head(3)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
mask = bond['Actor'] == 'Sean Connery'
bond[mask]

# %% [markdown]
# Evaluate `bond.where(mask)` — Jupyter renders the last expression as cell output.

# %%
bond.where(mask)

# %% [markdown]
# ## The .query Method

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
bond.sort_index(inplace = True)
bond.head(3)

# %% [markdown]
# Evaluate `bond.columns` — Jupyter renders the last expression as cell output.

# %%
bond.columns

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
bond.columns = (column_name.replace(" ", "_") for column_name in bond.columns)
bond.head(1)

# %% [markdown]
# Evaluate `bond.query('Actor == "Sean Connery"')` — Jupyter renders the last expression as cell output.

# %%
bond.query('Actor == "Sean Connery"')

# %% [markdown]
# Evaluate `bond.query('Director == "Terence Young"')` — Jupyter renders the last expression as cell output.

# %%
bond.query('Director == "Terence Young"')

# %% [markdown]
# Evaluate `bond.query("Actor != 'Roger Moore'")` — Jupyter renders the last expression as cell output.

# %%
bond.query("Actor != 'Roger Moore'")

# %% [markdown]
# Evaluate `bond.query('Box_Office > 600')` — Jupyter renders the last expression as cell output.

# %%
bond.query('Box_Office > 600')

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
bond.query("Actor == 'Roger Moore' or Director == 'John Glen'")

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
bond.query("Actor in('Timothy Dalton', 'George Lazenby')")

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
bond.query("Actor not in('Sean Connery', 'Roger Moore')")

# %% [markdown]
# ## A Review of the .apply () Method on Single Columns

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
bond.sort_index(inplace = True)
bond.head(3)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
def convert_to_string_and_add_millions(number):
    return str(number) + " MILLIONS!"

# %% [markdown]
# **Apply/Map:** Apply a function to each element, row, or column. `.apply()` works on rows/columns, `.map()` on individual elements. Use for custom transformations that aren't built into Pandas.

# %%
bond["Box Office"] = bond["Box Office"].apply(convert_to_string_and_add_millions)

# %% [markdown]
# **Apply/Map:** Apply a function to each element, row, or column. `.apply()` works on rows/columns, `.map()` on individual elements. Use for custom transformations that aren't built into Pandas.

# %%
bond["Budget"] = bond["Budget"].apply(convert_to_string_and_add_millions)

# %% [markdown]
# ## The .copy( ) Method

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
bond.sort_index(inplace = True)
bond.head(3)

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
directors = bond["Director"]
directors.head(3)

# %% [markdown]
# Access an element or slice using indexing — `directors["A View to a Kill"]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
directors["A View to a Kill"]

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
directors.head(3)
