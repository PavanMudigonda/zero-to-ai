# %% [markdown]
# Import the libraries needed for this section:
# - **pandas**

# %%
import pandas as pd

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.
#
# **GroupBy — Split-Apply-Combine:** One of the most powerful Pandas operations. It:
# 1. **Splits** the data by one or more keys (categories)
# 2. **Applies** a function to each group independently (mean, sum, count, custom)
# 3. **Combines** the results back into a DataFrame
#
# Example: `df.groupby('city')['price'].mean()` computes the average price per city.

# %%
fortune = pd.read_csv("fortune1000.csv", index_col="Rank")
sectors = fortune.groupby("Sector")
fortune.head()

# %% [markdown]
# Evaluate `type(sectors)` — Jupyter renders the last expression as cell output.

# %%
type(sectors)

# %% [markdown]
# Evaluate `len(sectors)` — Jupyter renders the last expression as cell output.

# %%
len(sectors)

# %% [markdown]
# Access an element or slice using indexing — `fortune["Sector"].nunique()`. Python uses zero-based indexing, so the first element is at index 0.

# %%
fortune["Sector"].nunique()

# %% [markdown]
# Evaluate `sectors.first()` — Jupyter renders the last expression as cell output.

# %%
sectors.first()

# %% [markdown]
# Evaluate `sectors.groups` — Jupyter renders the last expression as cell output.

# %%
sectors.groups

# %% [markdown]
# Access an element or slice using indexing — `fortune.loc[24,]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
fortune.loc[24,]

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.
#
# **GroupBy — Split-Apply-Combine:** One of the most powerful Pandas operations. It:
# 1. **Splits** the data by one or more keys (categories)
# 2. **Applies** a function to each group independently (mean, sum, count, custom)
# 3. **Combines** the results back into a DataFrame
#
# Example: `df.groupby('city')['price'].mean()` computes the average price per city.

# %%
fortune = pd.read_csv("fortune1000.csv", index_col="Rank")
sectors = fortune.groupby("Sector")
fortune.head()

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
sectors.get_group("Energy")
sectors.get_group("Technology")

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
sectors.max()
sectors.min()
sectors.sum()

# %% [markdown]
# Evaluate `sectors.get_group("Apparel")["Profits"].sum()` — Jupyter renders the last expression as cell output.

# %%
sectors.get_group("Apparel")["Profits"].sum()

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.
#
# **GroupBy — Split-Apply-Combine:** One of the most powerful Pandas operations. It:
# 1. **Splits** the data by one or more keys (categories)
# 2. **Applies** a function to each group independently (mean, sum, count, custom)
# 3. **Combines** the results back into a DataFrame
#
# Example: `df.groupby('city')['price'].mean()` computes the average price per city.

# %%
fortune = pd.read_csv("fortune1000.csv", index_col="Rank")
sectors = fortune.groupby(["Sector","Industry"])
fortune.head()

# %% [markdown]
# Evaluate `sectors.sum()` — Jupyter renders the last expression as cell output.

# %%
sectors.sum()

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.
#
# **GroupBy — Split-Apply-Combine:** One of the most powerful Pandas operations. It:
# 1. **Splits** the data by one or more keys (categories)
# 2. **Applies** a function to each group independently (mean, sum, count, custom)
# 3. **Combines** the results back into a DataFrame
#
# Example: `df.groupby('city')['price'].mean()` computes the average price per city.

# %%
fortune = pd.read_csv("fortune1000.csv", index_col="Rank")
sectors = fortune.groupby("Sector")
fortune.head()

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
sectors.agg({"Revenue":"sum",
            "Profits":"sum",
            "Employees":"mean"})

# %% [markdown]
# **Create a DataFrame:** Pandas DataFrames are 2D labeled data structures — they're the backbone of data science in Python. Each column can hold a different data type (numbers, strings, dates). DataFrames support powerful operations: filtering, grouping, merging, reshaping, and aggregation.

# %%
df = pd.DataFrame(columns= fortune.columns)

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
for sector, data in sectors:
    highest_revenue = data.nlargest(1, "Revenue")
    df = df.append(highest_revenue)

# %% [markdown]
# Evaluate `df` — Jupyter renders the last expression as cell output.

# %%
df

# %% [markdown]
# **GroupBy — Split-Apply-Combine:** One of the most powerful Pandas operations. It:
# 1. **Splits** the data by one or more keys (categories)
# 2. **Applies** a function to each group independently (mean, sum, count, custom)
# 3. **Combines** the results back into a DataFrame
#
# Example: `df.groupby('city')['price'].mean()` computes the average price per city.

# %%
cities = fortune.groupby("Location")

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
for sector, data in cities:
    highest_revenue = data.nlargest(1, "Revenue")
    df = df.append(highest_revenue)

# %% [markdown]
# Evaluate `df` — Jupyter renders the last expression as cell output.

# %%
df
