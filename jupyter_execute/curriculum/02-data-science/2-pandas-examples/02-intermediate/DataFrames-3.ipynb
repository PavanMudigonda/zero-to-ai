# %% [markdown]
# Import the libraries needed for this section:
# - **pandas**

# %%
import pandas as pd

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv("jamesbond.csv")
bond

# %% [markdown]
# Evaluate `bond.set_index("Film", inplace= True)` — Jupyter renders the last expression as cell output.

# %%
bond.set_index("Film", inplace= True)

# %% [markdown]
# Access an element or slice using indexing — `bond.loc["Goldfinger"]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond.loc["Goldfinger"]

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv("jamesbond.csv")

bond.loc[15]
bond.iloc[15]

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
bond.set_index("Film", inplace= True)
bond.sort_index(inplace = True)

# %% [markdown]
# Access an element or slice using indexing — `bond.iloc[14]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond.iloc[14]

# %% [markdown]
# Access an element or slice using indexing — `bond.loc["Octopussy"]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond.loc["Octopussy"]

# %% [markdown]
# Access an element or slice using indexing — `bond.ix["Octopussy"]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond.ix["Octopussy"]

# %% [markdown]
# Access an element or slice using indexing — `bond.ix[14]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond.ix[14]

# %% [markdown]
# Access an element or slice using indexing — `bond.loc["Octopussy",["Actor","Year"]]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond.loc["Octopussy",["Actor","Year"]]

# %% [markdown]
# Access an element or slice using indexing — `bond.iloc[14,[1,2,4]]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond.iloc[14,[1,2,4]]

# %% [markdown]
# **DataFrame Indexing:** Access specific rows/columns:
# - `.iloc[row, col]`: integer-based (position)
# - `.loc[label, col]`: label-based (index values)
# - `.drop()`: remove rows/columns by label

# %%
bond.iloc[14,[1]] = "Sir Roger Moore"

# %% [markdown]
# Access an element or slice using indexing — `bond["Actor"].unique()`. Python uses zero-based indexing, so the first element is at index 0.

# %%
bond["Actor"].unique()

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
mask = bond["Actor"] == "Sean Connery"

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
bond[mask]["Actor"] = "Sir Sean Connery"

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
df2 = bond["Actor"]
df2[mask]["Actor"] = "Sir Sean Connery"

# %% [markdown]
# Evaluate `df2` — Jupyter renders the last expression as cell output.

# %%
df2

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv("jamesbond.csv")
bond.rename(columns={"Year":"Release Date"})

# %% [markdown]
# Evaluate `bond.columns` — Jupyter renders the last expression as cell output.

# %%
bond.columns

# %% [markdown]
# **DataFrame Indexing:** Access specific rows/columns:
# - `.iloc[row, col]`: integer-based (position)
# - `.loc[label, col]`: label-based (index values)
# - `.drop()`: remove rows/columns by label

# %%
bond.drop("A View To Kill")

bond.drop("Box Office", axis = 1)

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv("jamesbond.csv")

# %% [markdown]
# Evaluate `bond.sample()` — Jupyter renders the last expression as cell output.

# %%
bond.sample()

# %% [markdown]
# Evaluate `bond.sample(5)` — Jupyter renders the last expression as cell output.

# %%
bond.sample(5)

# %% [markdown]
# bond.sample()

# %% [markdown]
# Evaluate `bond.sample(frac= .25)` — Jupyter renders the last expression as cell output.

# %%
bond.sample(frac= .25)

# %% [markdown]
# Evaluate `bond.nlargest(n = 4 , columns= "Box Office")` — Jupyter renders the last expression as cell output.

# %%
bond.nlargest(n = 4 , columns= "Box Office")

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
bond = pd.read_csv("jamesbond.csv")

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
mask = bond["Actor"] == "Sean Connery"
bond[mask]

# %% [markdown]
# Evaluate `bond.where()` — Jupyter renders the last expression as cell output.

# %%
bond.where()

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
bond.columns = [column_name.replace(" ","_") for column_name in bond.columns]

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
bond.head()

# %% [markdown]
# Evaluate `bond.query("Box_Office > 500")` — Jupyter renders the last expression as cell output.

# %%
bond.query("Box_Office > 500")

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
def convert_to_millions(number):
    return str(number) + " Millions!"

# %% [markdown]
# **Apply/Map:** Apply a function to each element, row, or column. `.apply()` works on rows/columns, `.map()` on individual elements. Use for custom transformations that aren't built into Pandas.

# %%
bond["Box Office"] = bond["Box Office"].apply(convert_to_millions)
bond["Box Office"]

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
directors = bond["Director"]

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
directors = bond["Director"].copy()

# %% [markdown]
# Evaluate `directors` — Jupyter renders the last expression as cell output.

# %%
directors

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
directors["Sam Mendes"] = "Sit Sam Mendes"

# %% [markdown]
# Evaluate `directors` — Jupyter renders the last expression as cell output.

# %%
directors

# %% [markdown]
# Evaluate `bond` — Jupyter renders the last expression as cell output.

# %%
bond
