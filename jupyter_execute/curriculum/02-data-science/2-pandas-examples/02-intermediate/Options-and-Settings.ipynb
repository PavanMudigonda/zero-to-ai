# %% [markdown]
# Import the libraries needed for this section:
# - **pandas**
# - **numpy**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
data = np.random.randint(1,100,[1000,50])

# %% [markdown]
# **Create a DataFrame:** Pandas DataFrames are 2D labeled data structures — they're the backbone of data science in Python. Each column can hold a different data type (numbers, strings, dates). DataFrames support powerful operations: filtering, grouping, merging, reshaping, and aggregation.

# %%
df = pd.DataFrame(data)

df.tail()

# %% [markdown]
# Evaluate `pd.options.display.max_rows` — Jupyter renders the last expression as cell output.

# %%
pd.options.display.max_rows

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
pd.options.display.max_rows = 2

# %% [markdown]
# Evaluate `df` — Jupyter renders the last expression as cell output.

# %%
df

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
pd.options.display.max_columns = 5

# %% [markdown]
# Evaluate `df` — Jupyter renders the last expression as cell output.

# %%
df

# %% [markdown]
# Evaluate `pd.get_option("max_columns")` — Jupyter renders the last expression as cell output.

# %%
pd.get_option("max_columns")

# %% [markdown]
# Evaluate `pd.set_option("max_columns",20)` — Jupyter renders the last expression as cell output.

# %%
pd.set_option("max_columns",20)

# %% [markdown]
# Evaluate `pd.reset_option` — Jupyter renders the last expression as cell output.

# %%
pd.reset_option

# %% [markdown]
# Evaluate `pd.describe_option("max_columns")` — Jupyter renders the last expression as cell output.

# %%
pd.describe_option("max_columns")

# %% [markdown]
# **Create a DataFrame:** Pandas DataFrames are 2D labeled data structures — they're the backbone of data science in Python. Each column can hold a different data type (numbers, strings, dates). DataFrames support powerful operations: filtering, grouping, merging, reshaping, and aggregation.

# %%
pd.DataFrame(np.random.randn(5,5))

# %% [markdown]
# Evaluate `pd.get_option("precision")` — Jupyter renders the last expression as cell output.

# %%
pd.get_option("precision")

# %% [markdown]
# Evaluate `pd.set_option("precision",2)` — Jupyter renders the last expression as cell output.

# %%
pd.set_option("precision",2)

# %% [markdown]
# Evaluate `df` — Jupyter renders the last expression as cell output.

# %%
df
