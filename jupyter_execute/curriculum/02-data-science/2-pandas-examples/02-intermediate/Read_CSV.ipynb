# %% [markdown]
# Import the libraries needed for this section:
# - **pandas**

# %%
import pandas as pd

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
pokemon = pd.read_csv("pokemon.csv", usecols=["Pokemon"],squeeze= True)
pokemon

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
google = pd.read_csv("google_stock_price.csv", squeeze= True)
google

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
pokemon.head(18)

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
pokemon.tail(14)

# %% [markdown]
# Evaluate `type(pokemon)` — Jupyter renders the last expression as cell output.

# %%
type(pokemon)

# %% [markdown]
# Evaluate `dict(google)` — Jupyter renders the last expression as cell output.

# %%
dict(google)

# %% [markdown]
# Evaluate `list(pokemon)` — Jupyter renders the last expression as cell output.

# %%
list(pokemon)

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.
#
# **Sort DataFrame:** Orders rows by one or more columns. Useful for finding top/bottom values, ranking features, and preparing data for sequential analysis.

# %%
pokemon.sort_values().head()

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
pokemon.name = "Pokemon Header"

# %% [markdown]
# **Sort DataFrame:** Orders rows by one or more columns. Useful for finding top/bottom values, ranking features, and preparing data for sequential analysis.

# %%
pokemon.sort_values(ascending= False)

# %% [markdown]
# **Sort DataFrame:** Orders rows by one or more columns. Useful for finding top/bottom values, ranking features, and preparing data for sequential analysis.

# %%
google.sort_values()

# %% [markdown]
# **Sort DataFrame:** Orders rows by one or more columns. Useful for finding top/bottom values, ranking features, and preparing data for sequential analysis.

# %%
google.sort_values(ascending= False, inplace = True)

# %% [markdown]
# **Preview Data:** `.head(n)` shows the first $n$ rows, `.tail(n)` the last. Always preview your data to verify it loaded correctly and understand its structure.

# %%
google.head()

# %% [markdown]
# Evaluate `pokemon.sort_index()` — Jupyter renders the last expression as cell output.

# %%
pokemon.sort_index()

# %% [markdown]
# Evaluate `pokemon` — Jupyter renders the last expression as cell output.

# %%
pokemon

# %% [markdown]
# Access an element or slice using indexing — `pokemon[4]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
pokemon[4]

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
pokemon = pd.read_csv("pokemon.csv", index_col= "Pokemon", squeeze= True)
pokemon

# %% [markdown]
# The code below implements the next step in this Pandas workflow. See the inline comments for details on each operation.

# %%
pokemon.get("Hoopa")
pokemon.get(key = "Noibat")

# %% [markdown]
# **DataFrame.describe():** Quick statistical summary — count, mean, std, min, max, and quartiles for each numeric column. First thing to run on new data to understand ranges, detect outliers, and check for missing values.

# %%
google.describe()

# %% [markdown]
# Evaluate `google.min()` — Jupyter renders the last expression as cell output.

# %%
google.min()

# %% [markdown]
# Evaluate `google.max()` — Jupyter renders the last expression as cell output.

# %%
google.max()

# %% [markdown]
# Evaluate `google.idxmin()` — Jupyter renders the last expression as cell output.

# %%
google.idxmin()

# %% [markdown]
# Access an element or slice using indexing — `google[11]`. Python uses zero-based indexing, so the first element is at index 0.

# %%
google[11]

# %% [markdown]
# **Value Counts:** Counts unique values in a column — reveals class balance, categorical distributions, and potential data quality issues.

# %%
pokemon.value_counts()

# %% [markdown]
# Evaluate `pokemon.count()` — Jupyter renders the last expression as cell output.

# %%
pokemon.count()

# %% [markdown]
# Evaluate `len(pokemon)` — Jupyter renders the last expression as cell output.

# %%
len(pokemon)

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
pokemon_names = pd.read_csv("pokemon.csv", usecols= ["Pokemon"], squeeze= True)

pokemon_types = pd.read_csv("pokemon.csv", index_col= "Pokemon", squeeze= True)

# %% [markdown]
# Evaluate `pokemon_names` — Jupyter renders the last expression as cell output.

# %%
pokemon_names

# %% [markdown]
# Evaluate `pokemon_types` — Jupyter renders the last expression as cell output.

# %%
pokemon_types

# %% [markdown]
# **Apply/Map:** Apply a function to each element, row, or column. `.apply()` works on rows/columns, `.map()` on individual elements. Use for custom transformations that aren't built into Pandas.

# %%
pokemon_names.map(pokemon_types)

# %% [markdown]
# **Load Data from CSV:** `pd.read_csv()` reads a comma-separated file into a Pandas DataFrame — the primary data structure for tabular data analysis. A DataFrame is like a spreadsheet: rows are observations, columns are features.
#
# Common parameters: `header`, `index_col`, `na_values`, `dtype`, `parse_dates`. For large files, use `chunksize` or `usecols` to load only what you need.

# %%
pokemon_names = pd.read_csv("pokemon.csv", usecols= ["Pokemon"], squeeze= True)

pokemon_types = pd.read_csv("pokemon.csv", index_col= "Pokemon", squeeze= True).to_dict()

# %% [markdown]
# Evaluate `pokemon_types` — Jupyter renders the last expression as cell output.

# %%
pokemon_types
