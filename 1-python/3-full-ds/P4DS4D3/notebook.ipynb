# %%
import matplotlib.image as img
import matplotlib.pyplot as plt

image = img.imread('Colorblk.jpg')
print(image)
plt.show()
plt.imshow(image)
# Out:
# [[[255 248 255]
#   [255 245 255]
#   [255 247 255]
#   ...
#   [254 255 255]
#   [254 255 255]
#   [254 255 255]]
#
#  [[249 255 244]
#   [251 255 250]
#   [249 255 253]
#   ...
#   [255 255 248]
#   [255 255 248]
#   [255 255 248]]
#
#  [[245 255 241]
#   [248 255 255]
#   [242 255 255]
#   ...
#   [255 255 251]
#   [255 255 251]
#   [255 255 251]]
#
#  ...
#
#  [[248 255 255]
#   [247 255 255]
#   [252 255 255]
#   ...
#   [255 247 255]
#   [255 239 255]
#   [255 240 255]]
#
#  [[255 255 255]
#   [252 255 255]
#   [254 255 255]
#   ...
#   [ 82  33  78]
#   [ 94  30  90]
#   [255 221 255]]
#
#  [[255 251 255]
#   [255 253 255]
#   [255 255 255]
#   ...
#   [255 230 255]
#   [255 224 255]
#   [ 99  22 102]]]
