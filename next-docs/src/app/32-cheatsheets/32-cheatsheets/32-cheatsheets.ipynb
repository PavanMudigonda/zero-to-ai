# %% [markdown]
# # Cheatsheets
#
# Fast command and workflow references for cloud, containers, DevOps, data, and AI/ML operations.
#
# ## Featured
#
# - [Docker and containers](../docker/) - Modern Docker, Compose, BuildKit, and container workflow references.
# - [Cloud and Terraform](../cloud/) - AWS, Azure, GCP, and Terraform commands for infrastructure and deployment work.
# - [AI and MLOps operations](../ai-ml/) - GPU compute, model serving, experiment tracking, and data pipelines.
#
# ## Platform and infrastructure
#
# - [Cloud CLIs](../cloud/) - AWS, Azure, GCP CLI commands and Terraform workflows.
# - [Docker](../docker/) - Docker commands, Compose workflows, and demo apps.
# - [Kubernetes](../k8s/) - kubectl, Helm, YAML examples, and cluster workflows.
# - [Linux](../linux/) - Linux command references for everyday shell work.
# - [Networking](../networking/) - Networking fundamentals and troubleshooting references.
# - [Monitoring](../monitoring/) - Prometheus and Grafana dashboards, alerts, and metrics.
#
# ## Developer workflow and delivery
#
# - [Git](../git/) - Git commands, workflows, and common recovery patterns.
# - [GitHub Actions](../github-actions/) - CI/CD pipelines, runners, and workflow examples.
# - [GitHub CLI](../github-cli/) - gh commands for pull requests, issues, and repo automation.
# - [Jenkins](../jenkins/) - Pipelines, shared libraries, and migration-oriented references.
# - [Shell scripting](../shell-scripting/) - Bash, YAML, JSON, PowerShell, and automation snippets.
# - [Config management](../config-management/) - Ansible and related automation patterns.
#
# ## Architecture, data, and interview prep
#
# - [Databases](../databases/) - SQL and database quick-reference material.
# - [DevOps architecture](../devops-architecture/) - CI/CD architecture, platform patterns, and flowcharts.
# - [System design](../system-design/) - System design questions, patterns, and study material.
# - [DevOps interviews](../devops-interviews/) - Interview questions and answer sets for practical prep.
# - [Cloud DevOps for AI/ML](../ai-ml/) - MLOps, cloud ML services, model serving, and GPU compute operations.
#
# ## Recently refreshed
#
# - [Docker commands cheatsheet](../docker/docker-commands-cheatsheet/) - Compose watch, Docker Scout, Docker Debug, and BuildKit-first workflows.
# - [Terraform commands cheatsheet](../cloud/terraform-commands-cheatsheet/) - Refresh-only workflows and newer GitHub Actions examples.
# - [YAML cheatsheet](../shell-scripting/yaml-cheatsheet/) - Current GitHub Actions versions and modern Node matrix examples.
# - [Jenkins cheatsheet](../jenkins/jenkins-cheatsheet/) - Pipeline references with corrected Actions migration snippets.
# - [GPU compute cheatsheet](../ai-ml/gpu-compute-cheatsheet/) - Stable gcloud billing budget commands and cloud GPU operations.
